# %%
# %matplotlib inline

import glob
import matplotlib
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import imageio as im
from keras import models
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
#! pip install ibm-cos-sdk
import ibm_boto3
from botocore.client import Config, ClientError
import types

# %%
#COS 인증정보 정의
IAM_SERVICE_ID= 'ServiceId-b5855f48-8bc3-4850-9635-9ed6e57f3f59'
IBM_API_KEY_ID='cXU9zBUwR1zcaKkcWBhxzfsafaY3V1wEv1o8uJOm4epA'
#IBM_API_KEY_ID='D-rPayJnbJj_q8aNEkCTIsU887Rzf_CP_q_wN8l59IOD'
ENDPOINT='https://s3.us.cloud-object-storage.appdomain.cloud'
IBM_AUTH_ENDPOINT= 'https://iam.ng.bluemix.net/oidc/token'
BUCKET='shapescan-donotdelete-pr-mgsuxvobpleqer'
COS_RESOURCE_CRN = "crn:v1:bluemix:public:cloud-object-storage:global:a/8d8f8f9cfc6fdd0b99e9f328b47ee768:855afe22-c6b1-4707-b1bf-23e1fcd64748::"

# %%
# Create resource
s3 = ibm_boto3.resource("s3",
    ibm_api_key_id=IBM_API_KEY_ID,
    ibm_service_instance_id=COS_RESOURCE_CRN,
    ibm_auth_endpoint=IBM_AUTH_ENDPOINT,
    config=Config(signature_version="oauth"),
    endpoint_url=ENDPOINT
)

# %%
# !ls -l
# Out:
# total 0

# %%
#다운로드 입력 파일
s3.Object(BUCKET, 'shapes.zip').download_file('shapes.zip')

# %%
# !ls -l
# Out:
# total 308
# -rw-r----- 1 dsxuser dsxuser 315291 May 30 13:39 shapes.zip

# %%
! unzip -o shapes.zip
# Out:
# Archive:  shapes.zip
#    creating: training_set/
#   inflating: training_set/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/training_set/
#   inflating: __MACOSX/training_set/._.DS_Store
#    creating: training_set/circles/
#   inflating: training_set/circles/drawing(48).png
#    creating: __MACOSX/training_set/circles/
#   inflating: __MACOSX/training_set/circles/._drawing(48).png
#   inflating: training_set/circles/drawing(33).png
#   inflating: __MACOSX/training_set/circles/._drawing(33).png
#   inflating: training_set/circles/drawing(64).png
#   inflating: __MACOSX/training_set/circles/._drawing(64).png
#   inflating: training_set/circles/drawing(25).png
#   inflating: __MACOSX/training_set/circles/._drawing(25).png
#   inflating: training_set/circles/drawing(52).png
#   inflating: __MACOSX/training_set/circles/._drawing(52).png
#   inflating: training_set/circles/drawing(7).png
#   inflating: __MACOSX/training_set/circles/._drawing(7).png
#   inflating: training_set/circles/drawing(13).png
#   inflating: __MACOSX/training_set/circles/._drawing(13).png
#   inflating: training_set/circles/drawing(44).png
#   inflating: __MACOSX/training_set/circles/._drawing(44).png
#   inflating: training_set/circles/drawing(68).png
#   inflating: __MACOSX/training_set/circles/._drawing(68).png
#   inflating: training_set/circles/drawing(29).png
#   inflating: __MACOSX/training_set/circles/._drawing(29).png
#   inflating: training_set/circles/drawing(28).png
#   inflating: __MACOSX/training_set/circles/._drawing(28).png
#   inflating: training_set/circles/drawing(69).png
#   inflating: __MACOSX/training_set/circles/._drawing(69).png
#   inflating: training_set/circles/drawing(45).png
#   inflating: __MACOSX/training_set/circles/._drawing(45).png
#   inflating: training_set/circles/drawing(12).png
#   inflating: __MACOSX/training_set/circles/._drawing(12).png
#   inflating: training_set/circles/drawing(53).png
#   inflating: __MACOSX/training_set/circles/._drawing(53).png
#   inflating: training_set/circles/drawing(6).png
#   inflating: __MACOSX/training_set/circles/._drawing(6).png
#   inflating: training_set/circles/drawing(24).png
#   inflating: __MACOSX/training_set/circles/._drawing(24).png
#   inflating: training_set/circles/drawing(65).png
#   inflating: __MACOSX/training_set/circles/._drawing(65).png
#   inflating: training_set/circles/drawing(32).png
#   inflating: __MACOSX/training_set/circles/._drawing(32).png
#   inflating: training_set/circles/drawing(49).png
#   inflating: __MACOSX/training_set/circles/._drawing(49).png
#   inflating: training_set/circles/drawing(1).png
#   inflating: __MACOSX/training_set/circles/._drawing(1).png
#   inflating: training_set/circles/drawing(54).png
#   inflating: __MACOSX/training_set/circles/._drawing(54).png
#   inflating: training_set/circles/drawing(15).png
#   inflating: __MACOSX/training_set/circles/._drawing(15).png
#   inflating: training_set/circles/drawing(42).png
#   inflating: __MACOSX/training_set/circles/._drawing(42).png
#   inflating: training_set/circles/drawing(39).png
#   inflating: __MACOSX/training_set/circles/._drawing(39).png
#   inflating: training_set/circles/drawing(58).png
#   inflating: __MACOSX/training_set/circles/._drawing(58).png
#   inflating: training_set/circles/drawing(19).png
#   inflating: __MACOSX/training_set/circles/._drawing(19).png
#   inflating: training_set/circles/drawing(35).png
#   inflating: __MACOSX/training_set/circles/._drawing(35).png
#   inflating: training_set/circles/drawing(62).png
#   inflating: __MACOSX/training_set/circles/._drawing(62).png
#   inflating: training_set/circles/drawing(23).png
#   inflating: __MACOSX/training_set/circles/._drawing(23).png
#   inflating: training_set/circles/drawing(22).png
#   inflating: __MACOSX/training_set/circles/._drawing(22).png
#   inflating: training_set/circles/drawing(63).png
#   inflating: __MACOSX/training_set/circles/._drawing(63).png
#   inflating: training_set/circles/drawing(34).png
#   inflating: __MACOSX/training_set/circles/._drawing(34).png
#   inflating: training_set/circles/drawing(18).png
#   inflating: __MACOSX/training_set/circles/._drawing(18).png
#   inflating: training_set/circles/drawing(59).png
#   inflating: __MACOSX/training_set/circles/._drawing(59).png
#   inflating: training_set/circles/drawing(38).png
#   inflating: __MACOSX/training_set/circles/._drawing(38).png
#   inflating: training_set/circles/drawing(43).png
#   inflating: __MACOSX/training_set/circles/._drawing(43).png
#   inflating: training_set/circles/drawing(14).png
#   inflating: __MACOSX/training_set/circles/._drawing(14).png
#   inflating: training_set/circles/drawing(55).png
#   inflating: __MACOSX/training_set/circles/._drawing(55).png
#   inflating: training_set/circles/drawing(40).png
#   inflating: __MACOSX/training_set/circles/._drawing(40).png
#   inflating: training_set/circles/drawing(17).png
#   inflating: __MACOSX/training_set/circles/._drawing(17).png
#   inflating: training_set/circles/drawing(56).png
#   inflating: __MACOSX/training_set/circles/._drawing(56).png
#   inflating: training_set/circles/drawing(3).png
#   inflating: __MACOSX/training_set/circles/._drawing(3).png
#   inflating: training_set/circles/drawing(21).png
#   inflating: __MACOSX/training_set/circles/._drawing(21).png
#   inflating: training_set/circles/drawing(60).png
#   inflating: __MACOSX/training_set/circles/._drawing(60).png
#   inflating: training_set/circles/drawing(37).png
#   inflating: __MACOSX/training_set/circles/._drawing(37).png
#   inflating: training_set/circles/drawing(36).png
#   inflating: __MACOSX/training_set/circles/._drawing(36).png
#   inflating: training_set/circles/drawing(61).png
#   inflating: __MACOSX/training_set/circles/._drawing(61).png
#   inflating: training_set/circles/drawing(20).png
#   inflating: __MACOSX/training_set/circles/._drawing(20).png
#   inflating: training_set/circles/drawing(57).png
#   inflating: __MACOSX/training_set/circles/._drawing(57).png
#   inflating: training_set/circles/drawing(2).png
#   inflating: __MACOSX/training_set/circles/._drawing(2).png
#   inflating: training_set/circles/drawing(16).png
#   inflating: __MACOSX/training_set/circles/._drawing(16).png
#   inflating: training_set/circles/drawing(41).png
#   inflating: __MACOSX/training_set/circles/._drawing(41).png
#   inflating: training_set/circles/drawing(27).png
#   inflating: __MACOSX/training_set/circles/._drawing(27).png
#   inflating: training_set/circles/drawing(70).png
#   inflating: __MACOSX/training_set/circles/._drawing(70).png
#   inflating: training_set/circles/drawing(66).png
#   inflating: __MACOSX/training_set/circles/._drawing(66).png
#   inflating: training_set/circles/drawing(31).png
#   inflating: __MACOSX/training_set/circles/._drawing(31).png
#   inflating: training_set/circles/drawing(9).png
#   inflating: __MACOSX/training_set/circles/._drawing(9).png
#   inflating: training_set/circles/drawing(46).png
#   inflating: __MACOSX/training_set/circles/._drawing(46).png
#   inflating: training_set/circles/drawing(11).png
#   inflating: __MACOSX/training_set/circles/._drawing(11).png
#   inflating: training_set/circles/drawing(5).png
#   inflating: __MACOSX/training_set/circles/._drawing(5).png
#   inflating: training_set/circles/drawing(50).png
#   inflating: __MACOSX/training_set/circles/._drawing(50).png
#   inflating: training_set/circles/drawing(4).png
#   inflating: __MACOSX/training_set/circles/._drawing(4).png
#   inflating: training_set/circles/drawing(51).png
#   inflating: __MACOSX/training_set/circles/._drawing(51).png
#   inflating: training_set/circles/drawing(10).png
#   inflating: __MACOSX/training_set/circles/._drawing(10).png
#   inflating: training_set/circles/drawing(47).png
#   inflating: __MACOSX/training_set/circles/._drawing(47).png
#   inflating: training_set/circles/drawing(8).png
#   inflating: __MACOSX/training_set/circles/._drawing(8).png
#   inflating: training_set/circles/drawing(30).png
#   inflating: __MACOSX/training_set/circles/._drawing(30).png
#   inflating: training_set/circles/drawing(67).png
#   inflating: __MACOSX/training_set/circles/._drawing(67).png
#   inflating: training_set/circles/drawing(26).png
#   inflating: __MACOSX/training_set/circles/._drawing(26).png
#   inflating: __MACOSX/training_set/._circles
#    creating: training_set/triangles/
#   inflating: training_set/triangles/drawing(48).png
#    creating: __MACOSX/training_set/triangles/
#   inflating: __MACOSX/training_set/triangles/._drawing(48).png
#   inflating: training_set/triangles/drawing(33).png
#   inflating: __MACOSX/training_set/triangles/._drawing(33).png
#   inflating: training_set/triangles/drawing(64).png
#   inflating: __MACOSX/training_set/triangles/._drawing(64).png
#   inflating: training_set/triangles/drawing(25).png
#   inflating: __MACOSX/training_set/triangles/._drawing(25).png
#   inflating: training_set/triangles/drawing(52).png
#   inflating: __MACOSX/training_set/triangles/._drawing(52).png
#   inflating: training_set/triangles/drawing(7).png
#   inflating: __MACOSX/training_set/triangles/._drawing(7).png
#   inflating: training_set/triangles/drawing(13).png
#   inflating: __MACOSX/training_set/triangles/._drawing(13).png
#   inflating: training_set/triangles/drawing(44).png
#   inflating: __MACOSX/training_set/triangles/._drawing(44).png
#   inflating: training_set/triangles/drawing(68).png
#   inflating: __MACOSX/training_set/triangles/._drawing(68).png
#   inflating: training_set/triangles/drawing(29).png
#   inflating: __MACOSX/training_set/triangles/._drawing(29).png
#   inflating: training_set/triangles/drawing(28).png
#   inflating: __MACOSX/training_set/triangles/._drawing(28).png
#   inflating: training_set/triangles/drawing(69).png
#   inflating: __MACOSX/training_set/triangles/._drawing(69).png
#   inflating: training_set/triangles/drawing(45).png
#   inflating: __MACOSX/training_set/triangles/._drawing(45).png
#   inflating: training_set/triangles/drawing(12).png
#   inflating: __MACOSX/training_set/triangles/._drawing(12).png
#   inflating: training_set/triangles/drawing(53).png
#   inflating: __MACOSX/training_set/triangles/._drawing(53).png
#   inflating: training_set/triangles/drawing(6).png
#   inflating: __MACOSX/training_set/triangles/._drawing(6).png
#   inflating: training_set/triangles/drawing(24).png
#   inflating: __MACOSX/training_set/triangles/._drawing(24).png
#   inflating: training_set/triangles/drawing(65).png
#   inflating: __MACOSX/training_set/triangles/._drawing(65).png
#   inflating: training_set/triangles/drawing(32).png
#   inflating: __MACOSX/training_set/triangles/._drawing(32).png
#   inflating: training_set/triangles/drawing(49).png
#   inflating: __MACOSX/training_set/triangles/._drawing(49).png
#   inflating: training_set/triangles/drawing(1).png
#   inflating: __MACOSX/training_set/triangles/._drawing(1).png
#   inflating: training_set/triangles/drawing(54).png
#   inflating: __MACOSX/training_set/triangles/._drawing(54).png
#   inflating: training_set/triangles/drawing(15).png
#   inflating: __MACOSX/training_set/triangles/._drawing(15).png
#   inflating: training_set/triangles/drawing(42).png
#   inflating: __MACOSX/training_set/triangles/._drawing(42).png
#   inflating: training_set/triangles/drawing(39).png
#   inflating: __MACOSX/training_set/triangles/._drawing(39).png
#   inflating: training_set/triangles/drawing(58).png
#   inflating: __MACOSX/training_set/triangles/._drawing(58).png
#   inflating: training_set/triangles/drawing(19).png
#   inflating: __MACOSX/training_set/triangles/._drawing(19).png
#   inflating: training_set/triangles/drawing(35).png
#   inflating: __MACOSX/training_set/triangles/._drawing(35).png
#   inflating: training_set/triangles/drawing(62).png
#   inflating: __MACOSX/training_set/triangles/._drawing(62).png
#   inflating: training_set/triangles/drawing(23).png
#   inflating: __MACOSX/training_set/triangles/._drawing(23).png
#   inflating: training_set/triangles/drawing(22).png
#   inflating: __MACOSX/training_set/triangles/._drawing(22).png
#   inflating: training_set/triangles/drawing(63).png
#   inflating: __MACOSX/training_set/triangles/._drawing(63).png
#   inflating: training_set/triangles/drawing(34).png
#   inflating: __MACOSX/training_set/triangles/._drawing(34).png
#   inflating: training_set/triangles/drawing(18).png
#   inflating: __MACOSX/training_set/triangles/._drawing(18).png
#   inflating: training_set/triangles/drawing(59).png
#   inflating: __MACOSX/training_set/triangles/._drawing(59).png
#   inflating: training_set/triangles/drawing(38).png
#   inflating: __MACOSX/training_set/triangles/._drawing(38).png
#   inflating: training_set/triangles/drawing(43).png
#   inflating: __MACOSX/training_set/triangles/._drawing(43).png
#   inflating: training_set/triangles/drawing(14).png
#   inflating: __MACOSX/training_set/triangles/._drawing(14).png
#   inflating: training_set/triangles/drawing(55).png
#   inflating: __MACOSX/training_set/triangles/._drawing(55).png
#   inflating: training_set/triangles/drawing(40).png
#   inflating: __MACOSX/training_set/triangles/._drawing(40).png
#   inflating: training_set/triangles/drawing(17).png
#   inflating: __MACOSX/training_set/triangles/._drawing(17).png
#   inflating: training_set/triangles/drawing(56).png
#   inflating: __MACOSX/training_set/triangles/._drawing(56).png
#   inflating: training_set/triangles/drawing(3).png
#   inflating: __MACOSX/training_set/triangles/._drawing(3).png
#   inflating: training_set/triangles/drawing(21).png
#   inflating: __MACOSX/training_set/triangles/._drawing(21).png
#   inflating: training_set/triangles/drawing(60).png
#   inflating: __MACOSX/training_set/triangles/._drawing(60).png
#   inflating: training_set/triangles/drawing(37).png
#   inflating: __MACOSX/training_set/triangles/._drawing(37).png
#   inflating: training_set/triangles/drawing(36).png
#   inflating: __MACOSX/training_set/triangles/._drawing(36).png
#   inflating: training_set/triangles/drawing(61).png
#   inflating: __MACOSX/training_set/triangles/._drawing(61).png
#   inflating: training_set/triangles/drawing(20).png
#   inflating: __MACOSX/training_set/triangles/._drawing(20).png
#   inflating: training_set/triangles/drawing(57).png
#   inflating: __MACOSX/training_set/triangles/._drawing(57).png
#   inflating: training_set/triangles/drawing(2).png
#   inflating: __MACOSX/training_set/triangles/._drawing(2).png
#   inflating: training_set/triangles/drawing(16).png
#   inflating: __MACOSX/training_set/triangles/._drawing(16).png
#   inflating: training_set/triangles/drawing(41).png
#   inflating: __MACOSX/training_set/triangles/._drawing(41).png
#   inflating: training_set/triangles/drawing(27).png
#   inflating: __MACOSX/training_set/triangles/._drawing(27).png
#   inflating: training_set/triangles/drawing(70).png
#   inflating: __MACOSX/training_set/triangles/._drawing(70).png
#   inflating: training_set/triangles/drawing(66).png
#   inflating: __MACOSX/training_set/triangles/._drawing(66).png
#   inflating: training_set/triangles/drawing(31).png
#   inflating: __MACOSX/training_set/triangles/._drawing(31).png
#   inflating: training_set/triangles/drawing(9).png
#   inflating: __MACOSX/training_set/triangles/._drawing(9).png
#   inflating: training_set/triangles/drawing(46).png
#   inflating: __MACOSX/training_set/triangles/._drawing(46).png
#   inflating: training_set/triangles/drawing(11).png
#   inflating: __MACOSX/training_set/triangles/._drawing(11).png
#   inflating: training_set/triangles/drawing(5).png
#   inflating: __MACOSX/training_set/triangles/._drawing(5).png
#   inflating: training_set/triangles/drawing(50).png
#   inflating: __MACOSX/training_set/triangles/._drawing(50).png
#   inflating: training_set/triangles/drawing(4).png
#   inflating: __MACOSX/training_set/triangles/._drawing(4).png
#   inflating: training_set/triangles/drawing(51).png
#   inflating: __MACOSX/training_set/triangles/._drawing(51).png
#   inflating: training_set/triangles/drawing(10).png
#   inflating: __MACOSX/training_set/triangles/._drawing(10).png
#   inflating: training_set/triangles/drawing(47).png
#   inflating: __MACOSX/training_set/triangles/._drawing(47).png
#   inflating: training_set/triangles/drawing(8).png
#   inflating: __MACOSX/training_set/triangles/._drawing(8).png
#   inflating: training_set/triangles/drawing(30).png
#   inflating: __MACOSX/training_set/triangles/._drawing(30).png
#   inflating: training_set/triangles/drawing(67).png
#   inflating: __MACOSX/training_set/triangles/._drawing(67).png
#   inflating: training_set/triangles/drawing(26).png
#   inflating: __MACOSX/training_set/triangles/._drawing(26).png
#   inflating: __MACOSX/training_set/._triangles
#    creating: training_set/squares/
#   inflating: training_set/squares/drawing(48).png
#    creating: __MACOSX/training_set/squares/
#   inflating: __MACOSX/training_set/squares/._drawing(48).png
#   inflating: training_set/squares/drawing(33).png
#   inflating: __MACOSX/training_set/squares/._drawing(33).png
#   inflating: training_set/squares/drawing(64).png
#   inflating: __MACOSX/training_set/squares/._drawing(64).png
#   inflating: training_set/squares/drawing(25).png
#   inflating: __MACOSX/training_set/squares/._drawing(25).png
#   inflating: training_set/squares/drawing(52).png
#   inflating: __MACOSX/training_set/squares/._drawing(52).png
#   inflating: training_set/squares/drawing(7).png
#   inflating: __MACOSX/training_set/squares/._drawing(7).png
#   inflating: training_set/squares/drawing(13).png
#   inflating: __MACOSX/training_set/squares/._drawing(13).png
#   inflating: training_set/squares/drawing(44).png
#   inflating: __MACOSX/training_set/squares/._drawing(44).png
#   inflating: training_set/squares/drawing(68).png
#   inflating: __MACOSX/training_set/squares/._drawing(68).png
#   inflating: training_set/squares/drawing(29).png
#   inflating: __MACOSX/training_set/squares/._drawing(29).png
#   inflating: training_set/squares/drawing(28).png
#   inflating: __MACOSX/training_set/squares/._drawing(28).png
#   inflating: training_set/squares/drawing(69).png
#   inflating: __MACOSX/training_set/squares/._drawing(69).png
#   inflating: training_set/squares/drawing(45).png
#   inflating: __MACOSX/training_set/squares/._drawing(45).png
#   inflating: training_set/squares/drawing(12).png
#   inflating: __MACOSX/training_set/squares/._drawing(12).png
#   inflating: training_set/squares/drawing(53).png
#   inflating: __MACOSX/training_set/squares/._drawing(53).png
#   inflating: training_set/squares/drawing(6).png
#   inflating: __MACOSX/training_set/squares/._drawing(6).png
#   inflating: training_set/squares/drawing(24).png
#   inflating: __MACOSX/training_set/squares/._drawing(24).png
#   inflating: training_set/squares/drawing(65).png
#   inflating: __MACOSX/training_set/squares/._drawing(65).png
#   inflating: training_set/squares/drawing(32).png
#   inflating: __MACOSX/training_set/squares/._drawing(32).png
#   inflating: training_set/squares/drawing(49).png
#   inflating: __MACOSX/training_set/squares/._drawing(49).png
#   inflating: training_set/squares/drawing(1).png
#   inflating: __MACOSX/training_set/squares/._drawing(1).png
#   inflating: training_set/squares/drawing(54).png
#   inflating: __MACOSX/training_set/squares/._drawing(54).png
#   inflating: training_set/squares/drawing(15).png
#   inflating: __MACOSX/training_set/squares/._drawing(15).png
#   inflating: training_set/squares/drawing(42).png
#   inflating: __MACOSX/training_set/squares/._drawing(42).png
#   inflating: training_set/squares/drawing(39).png
#   inflating: __MACOSX/training_set/squares/._drawing(39).png
#   inflating: training_set/squares/drawing(58).png
#   inflating: __MACOSX/training_set/squares/._drawing(58).png
#   inflating: training_set/squares/drawing(19).png
#   inflating: __MACOSX/training_set/squares/._drawing(19).png
#   inflating: training_set/squares/drawing(35).png
#   inflating: __MACOSX/training_set/squares/._drawing(35).png
#   inflating: training_set/squares/drawing(62).png
#   inflating: __MACOSX/training_set/squares/._drawing(62).png
#   inflating: training_set/squares/drawing(23).png
#   inflating: __MACOSX/training_set/squares/._drawing(23).png
#   inflating: training_set/squares/drawing(22).png
#   inflating: __MACOSX/training_set/squares/._drawing(22).png
#   inflating: training_set/squares/drawing(63).png
#   inflating: __MACOSX/training_set/squares/._drawing(63).png
#   inflating: training_set/squares/drawing(34).png
#   inflating: __MACOSX/training_set/squares/._drawing(34).png
#   inflating: training_set/squares/drawing(18).png
#   inflating: __MACOSX/training_set/squares/._drawing(18).png
#   inflating: training_set/squares/drawing(59).png
#   inflating: __MACOSX/training_set/squares/._drawing(59).png
#   inflating: training_set/squares/drawing(38).png
#   inflating: __MACOSX/training_set/squares/._drawing(38).png
#   inflating: training_set/squares/drawing(43).png
#   inflating: __MACOSX/training_set/squares/._drawing(43).png
#   inflating: training_set/squares/drawing(14).png
#   inflating: __MACOSX/training_set/squares/._drawing(14).png
#   inflating: training_set/squares/drawing(55).png
#   inflating: __MACOSX/training_set/squares/._drawing(55).png
#   inflating: training_set/squares/drawing(40).png
#   inflating: __MACOSX/training_set/squares/._drawing(40).png
#   inflating: training_set/squares/drawing(17).png
#   inflating: __MACOSX/training_set/squares/._drawing(17).png
#   inflating: training_set/squares/drawing(56).png
#   inflating: __MACOSX/training_set/squares/._drawing(56).png
#   inflating: training_set/squares/drawing(3).png
#   inflating: __MACOSX/training_set/squares/._drawing(3).png
#   inflating: training_set/squares/drawing(21).png
#   inflating: __MACOSX/training_set/squares/._drawing(21).png
#   inflating: training_set/squares/drawing(60).png
#   inflating: __MACOSX/training_set/squares/._drawing(60).png
#   inflating: training_set/squares/drawing(37).png
#   inflating: __MACOSX/training_set/squares/._drawing(37).png
#   inflating: training_set/squares/drawing(36).png
#   inflating: __MACOSX/training_set/squares/._drawing(36).png
#   inflating: training_set/squares/drawing(61).png
#   inflating: __MACOSX/training_set/squares/._drawing(61).png
#   inflating: training_set/squares/drawing(20).png
#   inflating: __MACOSX/training_set/squares/._drawing(20).png
#   inflating: training_set/squares/drawing(57).png
#   inflating: __MACOSX/training_set/squares/._drawing(57).png
#   inflating: training_set/squares/drawing(2).png
#   inflating: __MACOSX/training_set/squares/._drawing(2).png
#   inflating: training_set/squares/drawing(16).png
#   inflating: __MACOSX/training_set/squares/._drawing(16).png
#   inflating: training_set/squares/drawing(41).png
#   inflating: __MACOSX/training_set/squares/._drawing(41).png
#   inflating: training_set/squares/drawing(27).png
#   inflating: __MACOSX/training_set/squares/._drawing(27).png
#   inflating: training_set/squares/drawing(70).png
#   inflating: __MACOSX/training_set/squares/._drawing(70).png
#   inflating: training_set/squares/drawing(66).png
#   inflating: __MACOSX/training_set/squares/._drawing(66).png
#   inflating: training_set/squares/drawing(31).png
#   inflating: __MACOSX/training_set/squares/._drawing(31).png
#   inflating: training_set/squares/drawing(9).png
#   inflating: __MACOSX/training_set/squares/._drawing(9).png
#   inflating: training_set/squares/drawing(46).png
#   inflating: __MACOSX/training_set/squares/._drawing(46).png
#   inflating: training_set/squares/drawing(11).png
#   inflating: __MACOSX/training_set/squares/._drawing(11).png
#   inflating: training_set/squares/drawing(5).png
#   inflating: __MACOSX/training_set/squares/._drawing(5).png
#   inflating: training_set/squares/drawing(50).png
#   inflating: __MACOSX/training_set/squares/._drawing(50).png
#   inflating: training_set/squares/drawing(4).png
#   inflating: __MACOSX/training_set/squares/._drawing(4).png
#   inflating: training_set/squares/drawing(51).png
#   inflating: __MACOSX/training_set/squares/._drawing(51).png
#   inflating: training_set/squares/drawing(10).png
#   inflating: __MACOSX/training_set/squares/._drawing(10).png
#   inflating: training_set/squares/drawing(47).png
#   inflating: __MACOSX/training_set/squares/._drawing(47).png
#   inflating: training_set/squares/drawing(8).png
#   inflating: __MACOSX/training_set/squares/._drawing(8).png
#   inflating: training_set/squares/drawing(30).png
#   inflating: __MACOSX/training_set/squares/._drawing(30).png
#   inflating: training_set/squares/drawing(67).png
#   inflating: __MACOSX/training_set/squares/._drawing(67).png
#   inflating: training_set/squares/drawing(26).png
#   inflating: __MACOSX/training_set/squares/._drawing(26).png
#   inflating: __MACOSX/training_set/._squares
#    creating: test_set/
#   inflating: test_set/.DS_Store
#    creating: __MACOSX/test_set/
#   inflating: __MACOSX/test_set/._.DS_Store
#    creating: test_set/circles/
#   inflating: test_set/circles/drawing(72).png
#    creating: __MACOSX/test_set/circles/
#   inflating: __MACOSX/test_set/circles/._drawing(72).png
#   inflating: test_set/circles/drawing(87).png
#   inflating: __MACOSX/test_set/circles/._drawing(87).png
#   inflating: test_set/circles/drawing(91).png
#   inflating: __MACOSX/test_set/circles/._drawing(91).png
#   inflating: test_set/circles/drawing(90).png
#   inflating: __MACOSX/test_set/circles/._drawing(90).png
#   inflating: test_set/circles/drawing(86).png
#   inflating: __MACOSX/test_set/circles/._drawing(86).png
#   inflating: test_set/circles/drawing(73).png
#   inflating: __MACOSX/test_set/circles/._drawing(73).png
#   inflating: test_set/circles/drawing(81).png
#   inflating: __MACOSX/test_set/circles/._drawing(81).png
#   inflating: test_set/circles/drawing(97).png
#   inflating: __MACOSX/test_set/circles/._drawing(97).png
#   inflating: test_set/circles/drawing(78).png
#   inflating: __MACOSX/test_set/circles/._drawing(78).png
#   inflating: test_set/circles/drawing(74).png
#   inflating: __MACOSX/test_set/circles/._drawing(74).png
#   inflating: test_set/circles/drawing(75).png
#   inflating: __MACOSX/test_set/circles/._drawing(75).png
#   inflating: test_set/circles/drawing(96).png
#   inflating: __MACOSX/test_set/circles/._drawing(96).png
#   inflating: test_set/circles/drawing(79).png
#   inflating: __MACOSX/test_set/circles/._drawing(79).png
#   inflating: test_set/circles/drawing(80).png
#   inflating: __MACOSX/test_set/circles/._drawing(80).png
#   inflating: test_set/circles/drawing(95).png
#   inflating: __MACOSX/test_set/circles/._drawing(95).png
#   inflating: test_set/circles/drawing(83).png
#   inflating: __MACOSX/test_set/circles/._drawing(83).png
#   inflating: test_set/circles/drawing(76).png
#   inflating: __MACOSX/test_set/circles/._drawing(76).png
#   inflating: test_set/circles/drawing(99).png
#   inflating: __MACOSX/test_set/circles/._drawing(99).png
#   inflating: test_set/circles/drawing(77).png
#   inflating: __MACOSX/test_set/circles/._drawing(77).png
#   inflating: test_set/circles/drawing(98).png
#   inflating: __MACOSX/test_set/circles/._drawing(98).png
#   inflating: test_set/circles/drawing(82).png
#   inflating: __MACOSX/test_set/circles/._drawing(82).png
#   inflating: test_set/circles/drawing(94).png
#   inflating: __MACOSX/test_set/circles/._drawing(94).png
#   inflating: test_set/circles/drawing(89).png
#   inflating: __MACOSX/test_set/circles/._drawing(89).png
#   inflating: test_set/circles/drawing(93).png
#   inflating: __MACOSX/test_set/circles/._drawing(93).png
#   inflating: test_set/circles/drawing(85).png
#   inflating: __MACOSX/test_set/circles/._drawing(85).png
#   inflating: test_set/circles/drawing(84).png
#   inflating: __MACOSX/test_set/circles/._drawing(84).png
#   inflating: test_set/circles/drawing(92).png
#   inflating: __MACOSX/test_set/circles/._drawing(92).png
#   inflating: test_set/circles/drawing(88).png
#   inflating: __MACOSX/test_set/circles/._drawing(88).png
#   inflating: test_set/circles/drawing(71).png
#   inflating: __MACOSX/test_set/circles/._drawing(71).png
#   inflating: __MACOSX/test_set/._circles
#    creating: test_set/triangles/
#   inflating: test_set/triangles/drawing(72).png
#    creating: __MACOSX/test_set/triangles/
#   inflating: __MACOSX/test_set/triangles/._drawing(72).png
#   inflating: test_set/triangles/drawing(87).png
#   inflating: __MACOSX/test_set/triangles/._drawing(87).png
#   inflating: test_set/triangles/drawing(91).png
#   inflating: __MACOSX/test_set/triangles/._drawing(91).png
#   inflating: test_set/triangles/drawing(90).png
#   inflating: __MACOSX/test_set/triangles/._drawing(90).png
#   inflating: test_set/triangles/drawing(86).png
#   inflating: __MACOSX/test_set/triangles/._drawing(86).png
#   inflating: test_set/triangles/drawing(73).png
#   inflating: __MACOSX/test_set/triangles/._drawing(73).png
#   inflating: test_set/triangles/drawing(81).png
#   inflating: __MACOSX/test_set/triangles/._drawing(81).png
#   inflating: test_set/triangles/drawing(97).png
#   inflating: __MACOSX/test_set/triangles/._drawing(97).png
#   inflating: test_set/triangles/drawing(78).png
#   inflating: __MACOSX/test_set/triangles/._drawing(78).png
#   inflating: test_set/triangles/drawing(74).png
#   inflating: __MACOSX/test_set/triangles/._drawing(74).png
#   inflating: test_set/triangles/drawing(75).png
#   inflating: __MACOSX/test_set/triangles/._drawing(75).png
#   inflating: test_set/triangles/drawing(96).png
#   inflating: __MACOSX/test_set/triangles/._drawing(96).png
#   inflating: test_set/triangles/drawing(79).png
#   inflating: __MACOSX/test_set/triangles/._drawing(79).png
#   inflating: test_set/triangles/drawing(80).png
#   inflating: __MACOSX/test_set/triangles/._drawing(80).png
#   inflating: test_set/triangles/drawing(95).png
#   inflating: __MACOSX/test_set/triangles/._drawing(95).png
#   inflating: test_set/triangles/drawing(83).png
#   inflating: __MACOSX/test_set/triangles/._drawing(83).png
#   inflating: test_set/triangles/drawing(76).png
#   inflating: __MACOSX/test_set/triangles/._drawing(76).png
#   inflating: test_set/triangles/drawing(99).png
#   inflating: __MACOSX/test_set/triangles/._drawing(99).png
#   inflating: test_set/triangles/drawing(77).png
#   inflating: __MACOSX/test_set/triangles/._drawing(77).png
#   inflating: test_set/triangles/drawing(98).png
#   inflating: __MACOSX/test_set/triangles/._drawing(98).png
#   inflating: test_set/triangles/drawing(82).png
#   inflating: __MACOSX/test_set/triangles/._drawing(82).png
#   inflating: test_set/triangles/drawing(94).png
#   inflating: __MACOSX/test_set/triangles/._drawing(94).png
#   inflating: test_set/triangles/drawing(89).png
#   inflating: __MACOSX/test_set/triangles/._drawing(89).png
#   inflating: test_set/triangles/drawing(93).png
#   inflating: __MACOSX/test_set/triangles/._drawing(93).png
#   inflating: test_set/triangles/drawing(85).png
#   inflating: __MACOSX/test_set/triangles/._drawing(85).png
#   inflating: test_set/triangles/drawing(84).png
#   inflating: __MACOSX/test_set/triangles/._drawing(84).png
#   inflating: test_set/triangles/drawing(92).png
#   inflating: __MACOSX/test_set/triangles/._drawing(92).png
#   inflating: test_set/triangles/drawing(88).png
#   inflating: __MACOSX/test_set/triangles/._drawing(88).png
#   inflating: test_set/triangles/drawing(71).png
#   inflating: __MACOSX/test_set/triangles/._drawing(71).png
#   inflating: __MACOSX/test_set/._triangles
#    creating: test_set/squares/
#   inflating: test_set/squares/drawing(72).png
#    creating: __MACOSX/test_set/squares/
#   inflating: __MACOSX/test_set/squares/._drawing(72).png
#   inflating: test_set/squares/drawing(87).png
#   inflating: __MACOSX/test_set/squares/._drawing(87).png
#   inflating: test_set/squares/drawing(91).png
#   inflating: __MACOSX/test_set/squares/._drawing(91).png
#   inflating: test_set/squares/drawing(90).png
#   inflating: __MACOSX/test_set/squares/._drawing(90).png
#   inflating: test_set/squares/drawing(86).png
#   inflating: __MACOSX/test_set/squares/._drawing(86).png
#   inflating: test_set/squares/drawing(73).png
#   inflating: __MACOSX/test_set/squares/._drawing(73).png
#   inflating: test_set/squares/drawing(81).png
#   inflating: __MACOSX/test_set/squares/._drawing(81).png
#   inflating: test_set/squares/drawing(97).png
#   inflating: __MACOSX/test_set/squares/._drawing(97).png
#   inflating: test_set/squares/drawing(78).png
#   inflating: __MACOSX/test_set/squares/._drawing(78).png
#   inflating: test_set/squares/drawing(74).png
#   inflating: __MACOSX/test_set/squares/._drawing(74).png
#   inflating: test_set/squares/drawing(75).png
#   inflating: __MACOSX/test_set/squares/._drawing(75).png
#   inflating: test_set/squares/drawing(96).png
#   inflating: __MACOSX/test_set/squares/._drawing(96).png
#   inflating: test_set/squares/drawing(79).png
#   inflating: __MACOSX/test_set/squares/._drawing(79).png
#   inflating: test_set/squares/drawing(80).png
#   inflating: __MACOSX/test_set/squares/._drawing(80).png
#   inflating: test_set/squares/drawing(95).png
#   inflating: __MACOSX/test_set/squares/._drawing(95).png
#   inflating: test_set/squares/drawing(83).png
#   inflating: __MACOSX/test_set/squares/._drawing(83).png
#   inflating: test_set/squares/drawing(76).png
#   inflating: __MACOSX/test_set/squares/._drawing(76).png
#   inflating: test_set/squares/drawing(99).png
#   inflating: __MACOSX/test_set/squares/._drawing(99).png
#   inflating: test_set/squares/drawing(77).png
#   inflating: __MACOSX/test_set/squares/._drawing(77).png
#   inflating: test_set/squares/drawing(98).png
#   inflating: __MACOSX/test_set/squares/._drawing(98).png
#   inflating: test_set/squares/drawing(82).png
#   inflating: __MACOSX/test_set/squares/._drawing(82).png
#   inflating: test_set/squares/drawing(94).png
#   inflating: __MACOSX/test_set/squares/._drawing(94).png
#   inflating: test_set/squares/drawing(89).png
#   inflating: __MACOSX/test_set/squares/._drawing(89).png
#   inflating: test_set/squares/drawing(93).png
#   inflating: __MACOSX/test_set/squares/._drawing(93).png
#   inflating: test_set/squares/drawing(85).png
#   inflating: __MACOSX/test_set/squares/._drawing(85).png
#   inflating: test_set/squares/drawing(84).png
#   inflating: __MACOSX/test_set/squares/._drawing(84).png
#   inflating: test_set/squares/drawing(92).png
#   inflating: __MACOSX/test_set/squares/._drawing(92).png
#   inflating: test_set/squares/drawing(88).png
#   inflating: __MACOSX/test_set/squares/._drawing(88).png
#   inflating: test_set/squares/drawing(71).png
#   inflating: __MACOSX/test_set/squares/._drawing(71).png
#   inflating: __MACOSX/test_set/._squares

# %%
images = []
for img_path in glob.glob('training_set/circles/*.png'):
    images.append(mpimg.imread(img_path))

plt.figure(figsize=(20,10))
columns = 5
for i, image_circle in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image_circle)

# %%
images = []
for img_path in glob.glob('training_set/squares/*.png'):
    images.append(mpimg.imread(img_path))

plt.figure(figsize=(20,10))
columns = 5
for i, image_square in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image_square)

# %%
images = []
for img_path in glob.glob('training_set/triangles/*.png'):
    images.append(mpimg.imread(img_path))

plt.figure(figsize=(20,10))
columns = 5
for i, image_triangle in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image_triangle)

# %%
img = im.imread('training_set/squares/drawing(40).png')
img.shape
# Out:
# (28, 28, 3)

# %%
classifier = Sequential()

# %%
classifier.add(Conv2D(32, (3, 3), padding='same', input_shape = (28, 28, 3), activation = 'relu'))
classifier.add(Conv2D(32, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Dropout(0.5)) # antes era 0.25

# Adding a second convolutional layer
classifier.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
classifier.add(Conv2D(64, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Dropout(0.5)) # antes era 0.25

# Adding a third convolutional layer
classifier.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
classifier.add(Conv2D(64, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Dropout(0.5)) # antes era 0.25

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 512, activation = 'relu'))
classifier.add(Dropout(0.5)) 
classifier.add(Dense(units = 3, activation = 'softmax'))
# Out:
# WARNING:tensorflow:From /opt/conda/envs/Python36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/envs/Python36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
classifier.compile(optimizer = 'rmsprop',
                   loss = 'categorical_crossentropy', 
                   metrics = ['accuracy'])

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('training_set',
                                                 target_size = (28, 28),
                                                 batch_size = 16,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory('test_set',
                                            target_size = (28, 28),
                                            batch_size = 16,
                                            class_mode = 'categorical')
# Out:
# Found 210 images belonging to 3 classes.
# Found 87 images belonging to 3 classes.

# %%
checkpointer = ModelCheckpoint(filepath="best_weights.hdf5", 
                               monitor = 'val_acc',
                               verbose=1, 
                               save_best_only=True)

# %%
history = classifier.fit_generator(training_set,
                                   steps_per_epoch = 100,
                                   epochs = 8,
                                   callbacks=[checkpointer],
                                   validation_data = test_set,
                                   validation_steps = 50)
# Out:
# WARNING:tensorflow:From /opt/conda/envs/Python36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/8
# 100/100 [==============================] - 18s 181ms/step - loss: 1.1196 - acc: 0.3269 - val_loss: 1.1008 - val_acc: 0.3297
#
# Epoch 00001: val_acc improved from -inf to 0.32967, saving model to best_weights.hdf5
# Epoch 2/8
# 100/100 [==============================] - 16s 161ms/step - loss: 1.1082 - acc: 0.3307 - val_loss: 1.0820 - val_acc: 0.3338
#
# Epoch 00002: val_acc improved from 0.32967 to 0.33379, saving model to best_weights.hdf5
# Epoch 3/8
# 100/100 [==============================] - 15s 153ms/step - loss: 0.8001 - acc: 0.6412 - val_loss: 0.8849 - val_acc: 0.7274
#
# Epoch 00003: val_acc improved from 0.33379 to 0.72740, saving model to best_weights.hdf5
# Epoch 4/8
# 100/100 [==============================] - 16s 161ms/step - loss: 0.4676 - acc: 0.8025 - val_loss: 0.4128 - val_acc: 0.8599
#
# Epoch 00004: val_acc improved from 0.72740 to 0.85989, saving model to best_weights.hdf5
# Epoch 5/8
# 100/100 [==============================] - 16s 155ms/step - loss: 0.3122 - acc: 0.8755 - val_loss: 0.4241 - val_acc: 0.8887
#
# Epoch 00005: val_acc improved from 0.85989 to 0.88874, saving model to best_weights.hdf5
# Epoch 6/8
# 100/100 [==============================] - 16s 160ms/step - loss: 0.2205 - acc: 0.9262 - val_loss: 0.5039 - val_acc: 0.9082
#
# Epoch 00006: val_acc improved from 0.88874 to 0.90821, saving model to best_weights.hdf5
# Epoch 7/8
# 100/100 [==============================] - 15s 149ms/step - loss: 0.1657 - acc: 0.9425 - val_loss: 0.4478 - val_acc: 0.9093
#
# Epoch 00007: val_acc improved from 0.90821 to 0.90934, saving model to best_weights.hdf5
# Epoch 8/8
# 100/100 [==============================] - 16s 161ms/step - loss: 0.1534 - acc: 0.9581 - val_loss: 0.5714 - val_acc: 0.9313
#
# Epoch 00008: val_acc improved from 0.90934 to 0.93132, saving model to best_weights.hdf5

# %%
classifier.load_weights('best_weights.hdf5')
classifier.save('shapes_cnn.h5')

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
img_path = 'test_set/triangles/drawing(99).png'

img = image.load_img(img_path, target_size=(28, 28))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.

plt.imshow(img_tensor[0])
plt.show()

print(img_tensor.shape)
# Out:
# (1, 28, 28, 3)

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
classes = classifier.predict_classes(images, batch_size=10)
print("Predicted class is:",classes)
# Out:
# Predicted class is: [2]

# %%
layer_outputs = [layer.output for layer in classifier.layers[:12]] # Extracts the outputs of the top 12 layers
activation_model = models.Model(inputs=classifier.input, outputs=layer_outputs) # Creates a model that will return these outputs, given the model input

# %%
activations = activation_model.predict(img_tensor) # Returns a list of five Numpy arrays: one array per layer activation

# %%
first_layer_activation = activations[0]
print(first_layer_activation.shape)
# Out:
# (1, 28, 28, 32)

# %%
second_layer_activation = activations[1]
print(second_layer_activation.shape)
# Out:
# (1, 26, 26, 32)

# %%
plt.matshow(first_layer_activation[0, :, :, 3], cmap='viridis')

# %%
plt.matshow(second_layer_activation[0, :, :, 11], cmap='viridis')

# %%
layer_names = []
for layer in classifier.layers[:12]:
    layer_names.append(layer.name) # Names of the layers, so you can have them as part of your plot
    
images_per_row = 16

for layer_name, layer_activation in zip(layer_names, activations): # Displays the feature maps
    n_features = layer_activation.shape[-1] # Number of features in the feature map
    size = layer_activation.shape[1] #The feature map has shape (1, size, size, n_features).
    n_cols = n_features // images_per_row # Tiles the activation channels in this matrix
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    for col in range(n_cols): # Tiles each filter into a big horizontal grid
        for row in range(images_per_row):
            channel_image = layer_activation[0,
                                             :, :,
                                             col * images_per_row + row]
            channel_image -= channel_image.mean() # Post-processes the feature to make it visually palatable
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size, # Displays the grid
                         row * size : (row + 1) * size] = channel_image
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:18: RuntimeWarning: invalid value encountered in true_divide
