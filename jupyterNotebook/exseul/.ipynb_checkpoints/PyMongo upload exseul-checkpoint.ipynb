# %%
import pymongo
from pymongo import MongoClient

myclient = MongoClient('218.150.247.209:2017',
                       username='unsik',
                       password='next1004',
                       authSource='admin',
                       authMechanism='SCRAM-SHA-256')
# newDB = myclient['FriDB']
# oecd_doctCollection = newDB['OECDdoct']

import pandas as pd
import numpy as np

# %%
newDB = myclient['FriDB']
oecd_doctCollection = newDB['OECDdoct2']

# %%
#doct = pd.DataFrame(doctCollection.find({},{"_id":0}))
#doct[doct['의료인력']=='전문의']

# %%
oecd_Doct = pd.read_excel('../../data/OECD 성별 연령별 의사수.xlsx',thousands=',')

# %%
oecd_Doct
# Out:
#       성별     연령대  구분         Country  1980  1981  1982  1983  1984  1985  ...  \
# 0     여성      총합   값       Australia   Nan   Nan   Nan   Nan  4949  5472  ...
# 1     여성      총합   값         Austria   Nan   Nan   Nan   Nan   Nan   Nan  ...
# 2     여성      총합   값         Belgium   Nan   Nan   Nan   Nan   Nan   Nan  ...
# 3     여성      총합   값          Canada  4551  4911  5643  6216  6805  7574  ...
# 4     여성      총합   값           Chile   Nan   Nan   Nan   Nan   Nan   Nan  ...
# ...   ..     ...  ..             ...   ...   ...   ...   ...   ...   ...  ...
# 1333  총합  75세 이상  비율        Slovenia   Nan   Nan   Nan   Nan   Nan   Nan  ...
# 1334  총합  75세 이상  비율          Sweden   Nan   Nan   Nan   Nan   Nan   Nan  ...
# 1335  총합  75세 이상  비율     Switzerland   Nan   Nan   Nan   Nan   Nan   Nan  ...
# 1336  총합  75세 이상  비율          Turkey  0.44  0.42  0.42  0.43  0.42  0.43  ...
# 1337  총합  75세 이상  비율  United Kingdom   Nan   Nan   Nan   Nan   Nan   Nan  ...
#
#        2010   2011   2012   2013   2014   2015   2016   2017   2018   2019
# 0       Nan    Nan  28354  30021  31845  33370  35121  37318  39104    Nan
# 1     17833  18278  18773  19346  19914  20462  21065  21592  22062    Nan
# 2     11336  11743  12159  12686  13174  13822  14515  15049  15732    Nan
# 3     31424  33017  34876  36766  38284  39890  41247  42639  44921  46440
# 4      9417  10478  11155  12415  13988  15288  16725  18198  19762    Nan
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1333    Nan    Nan    Nan    Nan   0.16   0.12   0.18    0.3      0    Nan
# 1334    0.1      0      0      0      0      0      0      0    Nan    Nan
# 1335    0.7   0.81   0.84   0.95   1.05    1.2   1.32   1.51   1.75    Nan
# 1336   2.91   2.99   3.08   3.15   3.22   3.31   3.37   3.37   3.37    Nan
# 1337   0.06   0.06   0.07   0.08   0.08   0.08   0.09   0.11   0.14   0.16
#
# [1338 rows x 44 columns]

# %%
oecd_Doct = oecd_Doct.replace('Nan',-1)

# %%
oecd_Doct
# Out:
#       성별     연령대  구분         Country     1980     1981     1982     1983  \
# 0     여성      총합   값       Australia    -1.00    -1.00    -1.00    -1.00
# 1     여성      총합   값         Austria    -1.00    -1.00    -1.00    -1.00
# 2     여성      총합   값         Belgium    -1.00    -1.00    -1.00    -1.00
# 3     여성      총합   값          Canada  4551.00  4911.00  5643.00  6216.00
# 4     여성      총합   값           Chile    -1.00    -1.00    -1.00    -1.00
# ...   ..     ...  ..             ...      ...      ...      ...      ...
# 1333  총합  75세 이상  비율        Slovenia    -1.00    -1.00    -1.00    -1.00
# 1334  총합  75세 이상  비율          Sweden    -1.00    -1.00    -1.00    -1.00
# 1335  총합  75세 이상  비율     Switzerland    -1.00    -1.00    -1.00    -1.00
# 1336  총합  75세 이상  비율          Turkey     0.44     0.42     0.42     0.43
# 1337  총합  75세 이상  비율  United Kingdom    -1.00    -1.00    -1.00    -1.00
#
#          1984     1985  ...      2010      2011      2012      2013      2014  \
# 0     4949.00  5472.00  ...     -1.00     -1.00  28354.00  30021.00  31845.00
# 1       -1.00    -1.00  ...  17833.00  18278.00  18773.00  19346.00  19914.00
# 2       -1.00    -1.00  ...  11336.00  11743.00  12159.00  12686.00  13174.00
# 3     6805.00  7574.00  ...  31424.00  33017.00  34876.00  36766.00  38284.00
# 4       -1.00    -1.00  ...   9417.00  10478.00  11155.00  12415.00  13988.00
# ...       ...      ...  ...       ...       ...       ...       ...       ...
# 1333    -1.00    -1.00  ...     -1.00     -1.00     -1.00     -1.00      0.16
# 1334    -1.00    -1.00  ...      0.10      0.00      0.00      0.00      0.00
# 1335    -1.00    -1.00  ...      0.70      0.81      0.84      0.95      1.05
# 1336     0.42     0.43  ...      2.91      2.99      3.08      3.15      3.22
# 1337    -1.00    -1.00  ...      0.06      0.06      0.07      0.08      0.08
#
#           2015      2016      2017      2018      2019
# 0     33370.00  35121.00  37318.00  39104.00     -1.00
# 1     20462.00  21065.00  21592.00  22062.00     -1.00
# 2     13822.00  14515.00  15049.00  15732.00     -1.00
# 3     39890.00  41247.00  42639.00  44921.00  46440.00
# 4     15288.00  16725.00  18198.00  19762.00     -1.00
# ...        ...       ...       ...       ...       ...
# 1333      0.12      0.18      0.30      0.00     -1.00
# 1334      0.00      0.00      0.00     -1.00     -1.00
# 1335      1.20      1.32      1.51      1.75     -1.00
# 1336      3.31      3.37      3.37      3.37     -1.00
# 1337      0.08      0.09      0.11      0.14      0.16
#
# [1338 rows x 44 columns]

# %%
oecd_Doct.columns[4:]
# Out:
# Index(['1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
test_list = []
for i in range(len(oecd_Doct.index)):
    sex = oecd_Doct.iloc[i,0]
    age = oecd_Doct.iloc[i,1]
    x = oecd_Doct.iloc[i,2]
    country = oecd_Doct.iloc[i,3]
    for j in range(len(oecd_Doct.columns[4:])):
        year = oecd_Doct.columns[j+4]
        value = oecd_Doct.iloc[i,j+4]
        dic_doc = {"성별":sex,"연령대":age,"구분":x,"지역":country,"년도":int(year[0:4]),"값":float(value)}
        test_list.append(dic_doc)

print(type(test_list))
print(type(test_list[0]))
print(type(test_list[0]['년도']))
print(type(test_list[0]['값']))
# Out:
# <class 'list'>
# <class 'dict'>
# <class 'int'>
# <class 'float'>

# %%
test_list
# Out:
# [{'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1980,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1981,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1982,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1983,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1984,
#   '값': 4949.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1985,
#   '값': 5472.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1986,
#   '값': 6067.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1987,
#   '값': 6468.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1988,
#   '값': 6967.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1989,
#   '값': 7485.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1990,
#   '값': 7905.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1991,
#   '값': 9598.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1992,
#   '값': 10116.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1993,
#   '값': 10586.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1994,
#   '값': 11299.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1995,
#   '값': 11998.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1996,
#   '값': 12051.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1997,
#   '값': 12333.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1998,
#   '값': 12422.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 1999,
#   '값': 13197.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2000,
#   '값': 14192.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2001,
#   '값': 15125.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2002,
#   '값': 15728.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2003,
#   '값': 16569.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2004,
#   '값': 17458.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2005,
#   '값': 18452.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2006,
#   '값': 19664.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2007,
#   '값': 21352.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2008,
#   '값': 22533.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2009,
#   '값': 24211.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2010,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2011,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2012,
#   '값': 28354.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2013,
#   '값': 30021.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2014,
#   '값': 31845.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2015,
#   '값': 33370.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2016,
#   '값': 35121.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2017,
#   '값': 37318.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2018,
#   '값': 39104.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Australia',
#   '년도': 2019,
#   '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1980, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1981, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1982, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1983, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1984, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1985, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1986, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1987, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1988, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1989, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1990, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1991, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1992, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1993, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 1994, '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 1995,
#   '값': 9310.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 1996,
#   '값': 9605.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 1997,
#   '값': 10001.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 1998,
#   '값': 10597.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 1999,
#   '값': 10869.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2000,
#   '값': 11350.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2001,
#   '값': 11978.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2002,
#   '값': 12465.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2003,
#   '값': 13043.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2004,
#   '값': 13718.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2005,
#   '값': 14460.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2006,
#   '값': 15132.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2007,
#   '값': 15769.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2008,
#   '값': 16419.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2009,
#   '값': 17117.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2010,
#   '값': 17833.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2011,
#   '값': 18278.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2012,
#   '값': 18773.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2013,
#   '값': 19346.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2014,
#   '값': 19914.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2015,
#   '값': 20462.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2016,
#   '값': 21065.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2017,
#   '값': 21592.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Austria',
#   '년도': 2018,
#   '값': 22062.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Austria', '년도': 2019, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1980, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1981, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1982, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1983, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1984, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1985, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1986, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1987, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1988, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1989, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1990, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1991, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1992, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1993, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1994, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1995, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1996, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1997, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 1998, '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 1999,
#   '값': 7675.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2000,
#   '값': 8026.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2001,
#   '값': 8372.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2002,
#   '값': 8700.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2003,
#   '값': 8943.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2004,
#   '값': 9260.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2005,
#   '값': 9519.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2006,
#   '값': 9865.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2007,
#   '값': 10282.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2008,
#   '값': 10646.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2009,
#   '값': 11008.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2010,
#   '값': 11336.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2011,
#   '값': 11743.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2012,
#   '값': 12159.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2013,
#   '값': 12686.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2014,
#   '값': 13174.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2015,
#   '값': 13822.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2016,
#   '값': 14515.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2017,
#   '값': 15049.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Belgium',
#   '년도': 2018,
#   '값': 15732.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Belgium', '년도': 2019, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Canada', '년도': 1980, '값': 4551.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Canada', '년도': 1981, '값': 4911.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Canada', '년도': 1982, '값': 5643.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Canada', '년도': 1983, '값': 6216.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Canada', '년도': 1984, '값': 6805.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Canada', '년도': 1985, '값': 7574.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Canada', '년도': 1986, '값': 8189.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Canada', '년도': 1987, '값': 9077.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 1988,
#   '값': 12393.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 1989,
#   '값': 13325.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 1990,
#   '값': 13972.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 1991,
#   '값': 14717.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 1992,
#   '값': 15457.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 1993,
#   '값': 16233.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 1994,
#   '값': 16719.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 1995,
#   '값': 17226.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 1996,
#   '값': 17711.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 1997,
#   '값': 18132.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 1998,
#   '값': 18851.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 1999,
#   '값': 19546.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2000,
#   '값': 20196.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2001,
#   '값': 20946.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2002,
#   '값': 21733.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2003,
#   '값': 22196.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2004,
#   '값': 23279.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2005,
#   '값': 24293.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2006,
#   '값': 25357.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2007,
#   '값': 26612.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2008,
#   '값': 28034.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2009,
#   '값': 29991.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2010,
#   '값': 31424.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2011,
#   '값': 33017.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2012,
#   '값': 34876.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2013,
#   '값': 36766.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2014,
#   '값': 38284.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2015,
#   '값': 39890.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2016,
#   '값': 41247.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2017,
#   '값': 42639.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2018,
#   '값': 44921.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Canada',
#   '년도': 2019,
#   '값': 46440.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1980, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1981, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1982, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1983, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1984, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1985, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1986, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1987, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1988, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1989, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1990, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1991, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1992, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1993, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1994, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1995, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1996, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1997, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1998, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 1999, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2000, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2001, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2002, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2003, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2004, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2005, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2006, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2007, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2008, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2009, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2010, '값': 9417.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2011, '값': 10478.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2012, '값': 11155.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2013, '값': 12415.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2014, '값': 13988.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2015, '값': 15288.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2016, '값': 16725.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2017, '값': 18198.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2018, '값': 19762.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Chile', '년도': 2019, '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1980,
#   '값': 10773.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1981,
#   '값': 11225.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1982,
#   '값': 11693.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1983,
#   '값': 12248.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1984,
#   '값': 12647.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1985,
#   '값': 13055.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1986,
#   '값': 13274.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1987,
#   '값': 13449.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1988,
#   '값': 13865.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1989,
#   '값': 14122.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1990,
#   '값': 14239.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1991,
#   '값': 14098.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1992,
#   '값': 14202.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1993,
#   '값': 14864.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1994,
#   '값': 15444.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1995,
#   '값': 15791.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1996,
#   '값': 16038.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1997,
#   '값': 16490.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1998,
#   '값': 16326.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 1999,
#   '값': 16666.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2000,
#   '값': 17837.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2001,
#   '값': 18227.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2002,
#   '값': 18533.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2003,
#   '값': 18621.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2004,
#   '값': 18725.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2005,
#   '값': 19028.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2006,
#   '값': 19192.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2007,
#   '값': 19413.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2008,
#   '값': 19575.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2009,
#   '값': 19987.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2010,
#   '값': 20236.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2011,
#   '값': 20675.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2012,
#   '값': 21006.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2013,
#   '값': 21133.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2014,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2015,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2016,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2017,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2018,
#   '값': 24170.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Czech Republic',
#   '년도': 2019,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1980,
#   '값': 1828.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1981,
#   '값': 1930.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1982,
#   '값': 2302.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1983,
#   '값': 2435.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1984,
#   '값': 2719.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1985,
#   '값': 2832.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1986,
#   '값': 2982.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1987,
#   '값': 3094.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1988,
#   '값': 3242.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1989,
#   '값': 3466.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1990,
#   '값': 3599.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1991,
#   '값': 3699.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1992,
#   '값': 4004.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1993,
#   '값': 4093.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1994,
#   '값': 4253.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1995,
#   '값': 4434.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1996,
#   '값': 4629.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1997,
#   '값': 4958.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1998,
#   '값': 5239.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 1999,
#   '값': 5460.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2000,
#   '값': 5636.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2001,
#   '값': 5843.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2002,
#   '값': 6241.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2003,
#   '값': 6507.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2004,
#   '값': 6973.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2005,
#   '값': 7461.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2006,
#   '값': 7863.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2007,
#   '값': 8193.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2008,
#   '값': 8664.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2009,
#   '값': 9044.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2010,
#   '값': 9420.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2011,
#   '값': 9848.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2012,
#   '값': 10201.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2013,
#   '값': 10489.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2014,
#   '값': 10787.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2015,
#   '값': 11199.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2016,
#   '값': 11696.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2017,
#   '값': 12305.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Denmark',
#   '년도': 2018,
#   '값': 12844.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Denmark', '년도': 2019, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1980, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1981, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1982, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1983, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1984, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1985, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1986, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1987, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1988, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1989, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1990, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1991, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1992, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1993, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1994, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1995, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1996, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 1997, '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 1998,
#   '값': 3040.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 1999,
#   '값': 3043.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2000,
#   '값': 3003.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2001,
#   '값': 2827.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2002,
#   '값': 2978.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2003,
#   '값': 2999.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2004,
#   '값': 3010.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2005,
#   '값': 3115.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2006,
#   '값': 3142.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2007,
#   '값': 3247.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2008,
#   '값': 3315.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2009,
#   '값': 3243.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2010,
#   '값': 3206.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2011,
#   '값': 3243.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2012,
#   '값': 3213.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2013,
#   '값': 3311.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2014,
#   '값': 3323.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2015,
#   '값': 3350.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2016,
#   '값': 3378.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2017,
#   '값': 3382.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Estonia',
#   '년도': 2018,
#   '값': 3383.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Estonia', '년도': 2019, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1980, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1981, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1982, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1983, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1984, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1985, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1986, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1987, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1988, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1989, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1990, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1991, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1992, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1993, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1994, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1995, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1996, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1997, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 1998, '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 1999,
#   '값': 6991.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2000,
#   '값': 7395.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2001,
#   '값': 7504.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2002,
#   '값': 7713.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2003,
#   '값': 7915.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2004,
#   '값': 8122.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2005,
#   '값': 8375.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2006,
#   '값': 8613.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2007,
#   '값': 8781.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2008,
#   '값': 9036.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2009,
#   '값': 9309.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2010,
#   '값': 9723.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2011,
#   '값': 9874.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2012,
#   '값': 10119.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2013,
#   '값': 10257.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2014,
#   '값': 10797.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Finland',
#   '년도': 2015,
#   '값': 10540.03},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 2016, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 2017, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 2018, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Finland', '년도': 2019, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'France', '년도': 1980, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'France', '년도': 1981, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'France', '년도': 1982, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'France', '년도': 1983, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'France', '년도': 1984, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'France', '년도': 1985, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'France', '년도': 1986, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'France', '년도': 1987, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'France', '년도': 1988, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'France', '년도': 1989, '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 1990,
#   '값': 53347.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 1991,
#   '값': 55838.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 1992,
#   '값': 58287.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 1993,
#   '값': 60280.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 1994,
#   '값': 63628.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 1995,
#   '값': 65471.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 1996,
#   '값': 67419.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 1997,
#   '값': 69008.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 1998,
#   '값': 69911.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 1999,
#   '값': 70429.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2000,
#   '값': 72260.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2001,
#   '값': 74128.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2002,
#   '값': 75886.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2003,
#   '값': 77757.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2004,
#   '값': 79490.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2005,
#   '값': 80858.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2006,
#   '값': 82012.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2007,
#   '값': 83059.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2008,
#   '값': 84428.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2009,
#   '값': 84891.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2010,
#   '값': 86588.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2011,
#   '값': 78748.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2012,
#   '값': 81065.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2013,
#   '값': 83635.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2014,
#   '값': 86363.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2015,
#   '값': 88747.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2016,
#   '값': 91167.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2017,
#   '값': 93917.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'France',
#   '년도': 2018,
#   '값': 96236.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'France', '년도': 2019, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Germany', '년도': 1980, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Germany', '년도': 1981, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Germany', '년도': 1982, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Germany', '년도': 1983, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Germany', '년도': 1984, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Germany', '년도': 1985, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Germany', '년도': 1986, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Germany', '년도': 1987, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Germany', '년도': 1988, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Germany', '년도': 1989, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Germany', '년도': 1990, '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 1991,
#   '값': 71716.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 1992,
#   '값': 75050.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 1993,
#   '값': 79685.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 1994,
#   '값': 83309.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 1995,
#   '값': 86235.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 1996,
#   '값': 88529.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 1997,
#   '값': 89197.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 1998,
#   '값': 91433.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 1999,
#   '값': 93370.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2000,
#   '값': 96102.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2001,
#   '값': 98891.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2002,
#   '값': 101144.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2003,
#   '값': 103056.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2004,
#   '값': 105101.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2005,
#   '값': 107271.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2006,
#   '값': 110735.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2007,
#   '값': 114358.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2008,
#   '값': 118508.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2009,
#   '값': 123138.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2010,
#   '값': 128919.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2011,
#   '값': 134579.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2012,
#   '값': 139239.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2013,
#   '값': 145334.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2014,
#   '값': 150421.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2015,
#   '값': 154568.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2016,
#   '값': 159433.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2017,
#   '값': 163810.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Germany',
#   '년도': 2018,
#   '값': 168169.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Germany', '년도': 2019, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1980, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1981, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1982, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1983, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1984, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1985, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1986, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1987, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1988, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1989, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1990, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1991, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1992, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1993, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 1994, '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 1995,
#   '값': 12948.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 1996,
#   '값': 13050.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 1997,
#   '값': 14099.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 1998,
#   '값': 15008.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 1999,
#   '값': 15373.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2000,
#   '값': 16032.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2001,
#   '값': 16600.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2002,
#   '값': 17700.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2003,
#   '값': 18583.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2004,
#   '값': 19385.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2005,
#   '값': 20195.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2006,
#   '값': 22242.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2007,
#   '값': 23480.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2008,
#   '값': 24134.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2009,
#   '값': 24734.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2010,
#   '값': 24946.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2011,
#   '값': 25195.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2012,
#   '값': 25383.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2013,
#   '값': 25647.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2014,
#   '값': 26015.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2015,
#   '값': 25949.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2016,
#   '값': 28047.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2017,
#   '값': 27414.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Greece',
#   '년도': 2018,
#   '값': 27581.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Greece', '년도': 2019, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1980, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1981, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1982, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1983, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1984, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1985, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1986, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1987, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1988, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1989, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1990, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1991, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1992, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1993, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 1994, '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 1995,
#   '값': 17223.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 1996,
#   '값': 17420.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 1997,
#   '값': 17724.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 1998,
#   '값': 18118.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 1999,
#   '값': 18284.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2000,
#   '값': 15377.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2001,
#   '값': 16743.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2002,
#   '값': 19172.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2003,
#   '값': 19660.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2004,
#   '값': 17218.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2005,
#   '값': 14425.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2006,
#   '값': 15654.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2007,
#   '값': 14830.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2008,
#   '값': 16230.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2009,
#   '값': 15886.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2010,
#   '값': 15556.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2011,
#   '값': 16021.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2012,
#   '값': 16672.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2013,
#   '값': 17328.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2014,
#   '값': 17885.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2015,
#   '값': 17035.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2016,
#   '값': 17635.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2017,
#   '값': 18261.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Hungary',
#   '년도': 2018,
#   '값': 18557.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Hungary', '년도': 2019, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1980, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1981, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1982, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1983, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1984, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1985, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1986, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1987, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1988, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1989, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1990, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1991, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1992, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1993, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1994, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1995, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1996, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1997, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1998, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 1999, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 2000, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 2001, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 2002, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 2003, '값': 255.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 2004, '값': 267.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 2005, '값': 276.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 2006, '값': 295.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 2007, '값': 326.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 2008, '값': 359.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Iceland', '년도': 2009, '값': 373.0},
# ...
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2003,
#   '값': 9518.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2004,
#   '값': 9668.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2005,
#   '값': 9804.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2006,
#   '값': 10115.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2007,
#   '값': 9577.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2008,
#   '값': 9360.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2009,
#   '값': 9239.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2010,
#   '값': 9251.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2011,
#   '값': 9253.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2012,
#   '값': 9423.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2013,
#   '값': 9450.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2014,
#   '값': 9415.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2015,
#   '값': 9405.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2016,
#   '값': 9540.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2017,
#   '값': 9524.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2018,
#   '값': 9122.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Lithuania',
#   '년도': 2019,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1980,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1981,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1982,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1983,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1984,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1985,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1986,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1987,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1988,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1989,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1990,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1991,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1992,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1993,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1994,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1995,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1996,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1997,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1998,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 1999,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2000,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2001,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2002,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2003,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2004,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2005,
#   '값': 311.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2006,
#   '값': 340.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2007,
#   '값': 367.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2008,
#   '값': 373.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2009,
#   '값': 381.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2010,
#   '값': 418.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2011,
#   '값': 437.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2012,
#   '값': 463.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2013,
#   '값': 496.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2014,
#   '값': 540.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2015,
#   '값': 564.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2016,
#   '값': 581.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2017,
#   '값': 635.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2018,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Luxembourg',
#   '년도': 2019,
#   '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1980, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1981, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1982, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1983, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1984, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1985, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1986, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1987, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1988, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1989, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1990, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1991, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1992, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1993, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1994, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1995, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1996, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1997, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1998, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 1999, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2000, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2001, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2002, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2003, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2004, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2005, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2006, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2007, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2008, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2009, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2010, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2011, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2012, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2013, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2014, '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Mexico',
#   '년도': 2015,
#   '값': 124016.96},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Mexico',
#   '년도': 2016,
#   '값': 126348.17},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Mexico',
#   '년도': 2017,
#   '값': 130597.11},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2018, '값': -1.0},
#  {'성별': '여성', '연령대': '총합', '구분': '값', '지역': 'Mexico', '년도': 2019, '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1980,
#   '값': 5494.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1981,
#   '값': 5845.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1982,
#   '값': 6180.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1983,
#   '값': 6595.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1984,
#   '값': 7022.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1985,
#   '값': 7422.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1986,
#   '값': 7896.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1987,
#   '값': 8422.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1988,
#   '값': 8983.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1989,
#   '값': 9105.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1990,
#   '값': 9120.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1991,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1992,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1993,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1994,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1995,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1996,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1997,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1998,
#   '값': 15536.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 1999,
#   '값': 12917.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2000,
#   '값': 13731.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2001,
#   '값': 14664.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2002,
#   '값': 15485.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2003,
#   '값': 16153.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2004,
#   '값': 16870.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2005,
#   '값': 17700.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2006,
#   '값': 18661.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2007,
#   '값': 19356.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2008,
#   '값': 20722.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2009,
#   '값': 21779.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2010,
#   '값': 22677.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2011,
#   '값': 25092.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2012,
#   '값': 26955.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2013,
#   '값': 28140.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2014,
#   '값': 29840.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2015,
#   '값': 31170.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2016,
#   '값': 32280.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2017,
#   '값': 33699.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2018,
#   '값': 35060.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'Netherlands',
#   '년도': 2019,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1980,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1981,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1982,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1983,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1984,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1985,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1986,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1987,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1988,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1989,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1990,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1991,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1992,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1993,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1994,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1995,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1996,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1997,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1998,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 1999,
#   '값': -1.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2000,
#   '값': 3249.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2001,
#   '값': 3456.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2002,
#   '값': 3667.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2003,
#   '값': 3871.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2004,
#   '값': 4091.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2005,
#   '값': 4289.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2006,
#   '값': 4483.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2007,
#   '값': 4738.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2008,
#   '값': 5041.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2009,
#   '값': 5284.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2010,
#   '값': 5472.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2011,
#   '값': 5808.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2012,
#   '값': 5987.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2013,
#   '값': 6193.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2014,
#   '값': 6389.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2015,
#   '값': 6679.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2016,
#   '값': 7008.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2017,
#   '값': 7337.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2018,
#   '값': 7773.0},
#  {'성별': '여성',
#   '연령대': '총합',
#   '구분': '값',
#   '지역': 'New Zealand',
#   '년도': 2019,
#   '값': -1.0},
#  ...]

# %%
oecd_doctCollection.insert_many(test_list)

# %%
#과별 데이터 업로드
test_list = []
for i in range(len(mayjor_doc.index)):
    year = local_doc.iloc[i,0]
    for j in range(len(mayjor_doc.columns[2:])):
        subject = mayjor_doc.columns[j+2]
        value = mayjor_doc.iloc[i,j+2]
        dic_doc = {"년도":int(year), "과목":subject,"값":round(float(value),3)}
        test_list.append(dic_doc)

print(type(test_list))
print(type(test_list[0]))
print(type(test_list[0]['년도']))
print(type(test_list[0]['과목']))
# Out:
# <class 'list'>
# <class 'dict'>
# <class 'int'>
# <class 'str'>

# %%
mayjorCollection.insert_many(test_list)
# Out:
# [{'년도': 2013, '과목': '내과', '값': 18.077},
#  {'년도': 2013, '과목': '신경과', '값': 1.983},
#  {'년도': 2013, '과목': '정신건강의학과', '값': 4.168},
#  {'년도': 2013, '과목': '외과', '값': 7.873},
#  {'년도': 2013, '과목': '정형외과', '값': 7.373},
#  {'년도': 2013, '과목': '신경외과', '값': 3.382},
#  {'년도': 2013, '과목': '흉부외과', '값': 1.43},
#  {'년도': 2013, '과목': '성형외과', '값': 2.154},
#  {'년도': 2013, '과목': '마취통증의학과', '값': 5.267},
#  {'년도': 2013, '과목': '산부인과', '값': 7.683},
#  {'년도': 2013, '과목': '소아청소년과', '값': 7.153},
#  {'년도': 2013, '과목': '안과', '값': 3.957},
#  {'년도': 2013, '과목': '이비인후과', '값': 4.747},
#  {'년도': 2013, '과목': '피부과', '값': 2.57},
#  {'년도': 2013, '과목': '비뇨기과', '값': 3.328},
#  {'년도': 2013, '과목': '영상의학과', '값': 4.341},
#  {'년도': 2013, '과목': '방사선종양학과', '값': 0.334},
#  {'년도': 2013, '과목': '병리과', '값': 1.025},
#  {'년도': 2013, '과목': '진단검사의학과', '값': 1.001},
#  {'년도': 2013, '과목': '결핵과', '값': 0.115},
#  {'년도': 2013, '과목': '재활의학과', '값': 2.107},
#  {'년도': 2013, '과목': '핵의학과', '값': 0.246},
#  {'년도': 2013, '과목': '가정의학과', '값': 7.414},
#  {'년도': 2013, '과목': '응급의학과', '값': 1.505},
#  {'년도': 2013, '과목': '직업환경의학과', '값': 0.5},
#  {'년도': 2013, '과목': '예방의학과', '값': 0.263},
#  {'년도': 2014, '과목': '내과', '값': 18.204},
#  {'년도': 2014, '과목': '신경과', '값': 2.046},
#  {'년도': 2014, '과목': '정신건강의학과', '값': 4.187},
#  {'년도': 2014, '과목': '외과', '값': 7.762},
#  {'년도': 2014, '과목': '정형외과', '값': 7.303},
#  {'년도': 2014, '과목': '신경외과', '값': 3.383},
#  {'년도': 2014, '과목': '흉부외과', '값': 1.402},
#  {'년도': 2014, '과목': '성형외과', '값': 2.162},
#  {'년도': 2014, '과목': '마취통증의학과', '값': 5.287},
#  {'년도': 2014, '과목': '산부인과', '값': 7.471},
#  {'년도': 2014, '과목': '소아청소년과', '값': 7.066},
#  {'년도': 2014, '과목': '안과', '값': 3.952},
#  {'년도': 2014, '과목': '이비인후과', '값': 4.694},
#  {'년도': 2014, '과목': '피부과', '값': 2.558},
#  {'년도': 2014, '과목': '비뇨기과', '값': 3.295},
#  {'년도': 2014, '과목': '영상의학과', '값': 4.358},
#  {'년도': 2014, '과목': '방사선종양학과', '값': 0.349},
#  {'년도': 2014, '과목': '병리과', '값': 1.023},
#  {'년도': 2014, '과목': '진단검사의학과', '값': 1.007},
#  {'년도': 2014, '과목': '결핵과', '값': 0.114},
#  {'년도': 2014, '과목': '재활의학과', '값': 2.201},
#  {'년도': 2014, '과목': '핵의학과', '값': 0.26},
#  {'년도': 2014, '과목': '가정의학과', '값': 7.59},
#  {'년도': 2014, '과목': '응급의학과', '값': 1.562},
#  {'년도': 2014, '과목': '직업환경의학과', '값': 0.529},
#  {'년도': 2014, '과목': '예방의학과', '값': 0.237},
#  {'년도': 2015, '과목': '내과', '값': 18.363},
#  {'년도': 2015, '과목': '신경과', '값': 2.081},
#  {'년도': 2015, '과목': '정신건강의학과', '값': 4.161},
#  {'년도': 2015, '과목': '외과', '값': 7.596},
#  {'년도': 2015, '과목': '정형외과', '값': 7.362},
#  {'년도': 2015, '과목': '신경외과', '값': 3.385},
#  {'년도': 2015, '과목': '흉부외과', '값': 1.373},
#  {'년도': 2015, '과목': '성형외과', '값': 2.164},
#  {'년도': 2015, '과목': '마취통증의학과', '값': 5.314},
#  {'년도': 2015, '과목': '산부인과', '값': 7.361},
#  {'년도': 2015, '과목': '소아청소년과', '값': 6.991},
#  {'년도': 2015, '과목': '안과', '값': 3.944},
#  {'년도': 2015, '과목': '이비인후과', '값': 4.686},
#  {'년도': 2015, '과목': '피부과', '값': 2.549},
#  {'년도': 2015, '과목': '비뇨기과', '값': 3.226},
#  {'년도': 2015, '과목': '영상의학과', '값': 4.383},
#  {'년도': 2015, '과목': '방사선종양학과', '값': 0.355},
#  {'년도': 2015, '과목': '병리과', '값': 1.027},
#  {'년도': 2015, '과목': '진단검사의학과', '값': 1.01},
#  {'년도': 2015, '과목': '결핵과', '값': 0.106},
#  {'년도': 2015, '과목': '재활의학과', '값': 2.266},
#  {'년도': 2015, '과목': '핵의학과', '값': 0.266},
#  {'년도': 2015, '과목': '가정의학과', '값': 7.582},
#  {'년도': 2015, '과목': '응급의학과', '값': 1.661},
#  {'년도': 2015, '과목': '직업환경의학과', '값': 0.56},
#  {'년도': 2015, '과목': '예방의학과', '값': 0.229},
#  {'년도': 2016, '과목': '내과', '값': 18.472},
#  {'년도': 2016, '과목': '신경과', '값': 2.132},
#  {'년도': 2016, '과목': '정신건강의학과', '값': 4.157},
#  {'년도': 2016, '과목': '외과', '값': 7.511},
#  {'년도': 2016, '과목': '정형외과', '값': 7.371},
#  {'년도': 2016, '과목': '신경외과', '값': 3.365},
#  {'년도': 2016, '과목': '흉부외과', '값': 1.35},
#  {'년도': 2016, '과목': '성형외과', '값': 2.259},
#  {'년도': 2016, '과목': '마취통증의학과', '값': 5.342},
#  {'년도': 2016, '과목': '산부인과', '값': 7.142},
#  {'년도': 2016, '과목': '소아청소년과', '값': 6.936},
#  {'년도': 2016, '과목': '안과', '값': 3.945},
#  {'년도': 2016, '과목': '이비인후과', '값': 4.643},
#  {'년도': 2016, '과목': '피부과', '값': 2.531},
#  {'년도': 2016, '과목': '비뇨기과', '값': 3.183},
#  {'년도': 2016, '과목': '영상의학과', '값': 4.402},
#  {'년도': 2016, '과목': '방사선종양학과', '값': 0.358},
#  {'년도': 2016, '과목': '병리과', '값': 1.005},
#  {'년도': 2016, '과목': '진단검사의학과', '값': 0.993},
#  {'년도': 2016, '과목': '결핵과', '값': 0.097},
#  {'년도': 2016, '과목': '재활의학과', '값': 2.354},
#  {'년도': 2016, '과목': '핵의학과', '값': 0.271},
#  {'년도': 2016, '과목': '가정의학과', '값': 7.601},
#  {'년도': 2016, '과목': '응급의학과', '값': 1.768},
#  {'년도': 2016, '과목': '직업환경의학과', '값': 0.588},
#  {'년도': 2016, '과목': '예방의학과', '값': 0.225},
#  {'년도': 2017, '과목': '내과', '값': 18.547},
#  {'년도': 2017, '과목': '신경과', '값': 2.14},
#  {'년도': 2017, '과목': '정신건강의학과', '값': 4.208},
#  {'년도': 2017, '과목': '외과', '값': 7.344},
#  {'년도': 2017, '과목': '정형외과', '값': 7.314},
#  {'년도': 2017, '과목': '신경외과', '값': 3.339},
#  {'년도': 2017, '과목': '흉부외과', '값': 1.31},
#  {'년도': 2017, '과목': '성형외과', '값': 2.311},
#  {'년도': 2017, '과목': '마취통증의학과', '값': 5.368},
#  {'년도': 2017, '과목': '산부인과', '값': 6.988},
#  {'년도': 2017, '과목': '소아청소년과', '값': 6.925},
#  {'년도': 2017, '과목': '안과', '값': 3.993},
#  {'년도': 2017, '과목': '이비인후과', '값': 4.633},
#  {'년도': 2017, '과목': '피부과', '값': 2.57},
#  {'년도': 2017, '과목': '비뇨기과', '값': 3.108},
#  {'년도': 2017, '과목': '영상의학과', '값': 4.409},
#  {'년도': 2017, '과목': '방사선종양학과', '값': 0.353},
#  {'년도': 2017, '과목': '병리과', '값': 0.999},
#  {'년도': 2017, '과목': '진단검사의학과', '값': 1.012},
#  {'년도': 2017, '과목': '결핵과', '값': 0.084},
#  {'년도': 2017, '과목': '재활의학과', '값': 2.393},
#  {'년도': 2017, '과목': '핵의학과', '값': 0.278},
#  {'년도': 2017, '과목': '가정의학과', '값': 7.686},
#  {'년도': 2017, '과목': '응급의학과', '값': 1.861},
#  {'년도': 2017, '과목': '직업환경의학과', '값': 0.598},
#  {'년도': 2017, '과목': '예방의학과', '값': 0.228},
#  {'년도': 2018, '과목': '내과', '값': 18.674},
#  {'년도': 2018, '과목': '신경과', '값': 2.182},
#  {'년도': 2018, '과목': '정신건강의학과', '값': 4.217},
#  {'년도': 2018, '과목': '외과', '값': 7.244},
#  {'년도': 2018, '과목': '정형외과', '값': 7.357},
#  {'년도': 2018, '과목': '신경외과', '값': 3.307},
#  {'년도': 2018, '과목': '흉부외과', '값': 1.309},
#  {'년도': 2018, '과목': '성형외과', '값': 2.312},
#  {'년도': 2018, '과목': '마취통증의학과', '값': 5.368},
#  {'년도': 2018, '과목': '산부인과', '값': 6.846},
#  {'년도': 2018, '과목': '소아청소년과', '값': 6.819},
#  {'년도': 2018, '과목': '안과', '값': 4.017},
#  {'년도': 2018, '과목': '이비인후과', '값': 4.612},
#  {'년도': 2018, '과목': '피부과', '값': 2.594},
#  {'년도': 2018, '과목': '비뇨기과', '값': 3.068},
#  {'년도': 2018, '과목': '영상의학과', '값': 4.378},
#  {'년도': 2018, '과목': '방사선종양학과', '값': 0.354},
#  {'년도': 2018, '과목': '병리과', '값': 1.004},
#  {'년도': 2018, '과목': '진단검사의학과', '값': 1.011},
#  {'년도': 2018, '과목': '결핵과', '값': 0.072},
#  {'년도': 2018, '과목': '재활의학과', '값': 2.435},
#  {'년도': 2018, '과목': '핵의학과', '값': 0.28},
#  {'년도': 2018, '과목': '가정의학과', '값': 7.747},
#  {'년도': 2018, '과목': '응급의학과', '값': 1.964},
#  {'년도': 2018, '과목': '직업환경의학과', '값': 0.612},
#  {'년도': 2018, '과목': '예방의학과', '값': 0.218}]

# %%
mayjorCollection.find({"과목":"내과"})
