# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataOriDf = pd.read_excel('../../data/의사고시현황.xlsx')

# %%
pd.set_option('display.max_row', 1200)
pd.set_option('display.max_columns', 100)

# %%
dataOriDf[['연도','직종','성별','연령대','졸업여부','합격여부','회차']].groupby(['연도','직종','성별','연령대','졸업여부','합격여부']).count()
# Out:
#                                 회차
# 연도   직종     성별 연령대 졸업여부 합격여부
# 2001 의사     남  20  졸업   불합격     28
#                         합격      22
#                    졸업예정 결시      12
#                         불합격    197
#                         합격    1701
#                30  졸업   결시       8
#                         불합격     74
#                         합격      24
#                    졸업예정 결시       8
#                         불합격     77
#                         합격     250
#                40  졸업   결시       4
#                         불합격     20
#                         합격       4
#                    졸업예정 불합격      1
#                         합격       3
#                50  졸업   결시       1
#                         불합격      5
#                60  졸업   불합격      2
#             여  20  졸업   불합격      6
#                         합격       4
#                    졸업예정 결시       3
#                         불합격     35
#                         합격     740
#                30  졸업   결시       2
# ...
