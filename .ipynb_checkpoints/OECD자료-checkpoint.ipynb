# %%
import pandas as pd
import matplotlib.pyplot as plt

data_df = pd.read_excel('OECD의사수.xlsx')
# Variable 0:Practising physicians / 1:Professionally active physicians / 2:Physicians licensed to practice
# Measure 0:Number of persons (head counts) / 1: Density per 1 000 population (head counts)
# OECD 0: OECD Economies / 1: Non-OECD Economies
print(data_df)
# Out:
#      Variable  Measure  OECD         Country      2000      2001      2002  \
# 0           0        0     1       Australia  47372.00  49392.00  49895.00
# 1           0        0     1         Austria  30871.00  31859.00  32575.00
# 2           0        0     1         Belgium  28999.00  29303.00  29537.00
# 3           0        0     1          Canada  61748.00  62488.00  63498.00
# 4           0        0     1        Colombia  49406.00  51209.00  53266.00
# ..        ...      ...   ...             ...       ...       ...       ...
# 181         2        1     1        Portugal      3.08      3.13      3.16
# 182         2        1     1           Spain      4.41      4.42      4.49
# 183         2        1     1          Sweden      4.19      4.31      4.44
# 184         2        1     1  United Kingdom      3.43      3.48      3.52
# 185         2        1     1   United States      2.88      2.93      2.97
#
# ...

# %%
meanData_df = data_df.groupby(['Variable','Measure','OECD']).mean()

# %%
meanData_df
# Out:
#                                 2000           2001           2002  \
# Variable Measure OECD
# 0        0       0     768837.500000  784250.750000  751913.000000
#                  1      83938.033333   79865.275862   86960.433333
#          1       0          1.942500       1.960000       1.952500
#                  1          2.685667       2.732414       2.749333
# 1        0       1     105389.682381  100223.966500  109133.777619
#          1       1          2.962381       3.027500       3.012381
# 2        0       1     116552.590909  110941.583333  113488.208333
#          1       1          3.600455       3.649583       3.722083
#
#                                 2003           2004           2005  \
# Variable Measure OECD
# 0        0       0     778409.500000  801655.000000  824624.250000
#                  1      81574.166667   89070.419355   87512.172414
#          1       0          1.990000       2.040000       2.077500
# ...

# %%
y1 = meanData_df.iloc[2:3,:]
y2 = meanData_df.iloc[3:4,:]
y3 = meanData_df.iloc[4:5,:]

# %%
yearList = arange(2000,2020)
plt.plot(yearList, y1,label='OECD', color='blue', alpha = 0.3)  # label 설정값을 legend에 나타날 수 있음
plt.plot(yearList, y2, label='1+cos', color='red', alpha = 0.7)

plt.xlabel("x value")
plt.ylabel("y value")

plt.title("sin and cos graph", fontsize = 18)
plt.grid()
plt.legend()

plt.show()
