# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
import connectDB
import pandas as pd
import plotly.graph_objects as go

# DB 연결
myclient = connectDB.connectDB()

myDB = myclient['FriDB']
popCol = myDB['Population']
popCol2 = myDB['Population2']
csdCol = myDB['CitySubjectDoc']

popDF = pd.DataFrame(popCol.find({}, {'_id': 0}))
csdDF = pd.DataFrame(csdCol.find({}, {'_id': 0}))

# %%
def makeFigure():
    
    
    fig = px.bar(csdDF,
                 x='값',
                 y='과목',
                 height=1000,
                 range_x=[0, 16000],
                 orientation='h',
                 color='지역',
                 animation_frame='년도'
                 )

    fig.update_layout(
        margin=dict(l=0, r=0, t=100, b=0),
        font=dict(family='Malgun Gothic', size=13, color='rgb(67, 67, 67)'),
        yaxis=dict(categoryorder='total ascending'),
        updatemenus=[{'buttons': [{'args': [None, {'frame': {'duration':
                                                             1000, 'redraw': True}, 'mode':
                                                   'immediate', 'fromcurrent':
                                                   True, 'transition':
                                                   {'duration': 1000, 'easing':
                                                       'quadratic-in-out'}}]}]}]
    )

    return fig

# %%
csdDF
# Out:
#          과목    년도  지역     값
# 0        내과  2005  서울  2266
# 1        내과  2005  부산   690
# 2        내과  2005  대구   489
# 3        내과  2005  인천   360
# 4        내과  2005  광주   316
# ...     ...   ...  ..   ...
# 6183  예방의학과  2018  전북     5
# 6184  예방의학과  2018  전남     7
# 6185  예방의학과  2018  경북    17
# 6186  예방의학과  2018  경남    11
# 6187  예방의학과  2018  제주     2
#
# [6188 rows x 4 columns]

# %%
popDF = popDF[popDF['구분']=='계']
popDF = popDF[popDF['구간']=='총 인구수']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '구간'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-4808afc5af0b> in <module>
#       1 popDF = popDF[popDF['구분']=='계']
# ----> 2 popDF = popDF[popDF['구간']=='총 인구수']
#       3 popDF.groupby('행정기관').mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: '구간'

# %%
popDF = pd.DataFrame(popCol.find({}, {'_id': 0}))
popDF.groupby('행정기관').mean()
# Out:
#                  인구수
# 행정기관
# 가평군     38427.047619
# 강남구    370063.619048
# 강동구    320823.952381
# 강릉시    142971.428571
# 강북구    231875.546667
# ...              ...
# 화천군     16817.571429
# 회원구    139640.916667
# 횡성군     30638.261905
# 효자출장소   96516.222222
# 흥덕구    226794.240000
#
# [336 rows x 1 columns]

# %%
popDF = pd.read_excel('data/1992_2019 행정구역 시군구별 성별 인구수.xlsx',thousands = ',')

popDF = popDF.fillna(0)
dataList = []
for i in range(len(popDF.index)):
    for j in range(len(popDF.columns[3:])):
       dataList.append({'행정기관': popDF.iloc[i,0], '구분': popDF.iloc[i,1], '인구수': int(popDF.iloc[i,j+3]), '년도': int(popDF.columns[j+3][0:4])})

# %%
dataList[0]
# Out:
# {'행정기관': '전국', '구분': '총인구수', '인구수': 44503200, '년도': 1992}

# %%
popCol2.insert_many(dataList)

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
import connectDB
import pandas as pd
import plotly.graph_objects as go

# DB 연결
myclient = connectDB.connectDB()

myDB = myclient['FriDB']
popCol = myDB['Population2']
csdCol = myDB['CitySubjectDoc']

popDF = pd.DataFrame(popCol.find({}, {'_id': 0}))
csdDF = pd.DataFrame(csdCol.find({}, {'_id': 0}))

popAllDF = popDF[popDF['행정기관'] == '전국']
popAllDF = popAllDF[popDF['구분'] == '총인구수']
resultDF = popDF.iloc[13:, 2:4]
pd.DataFrame.reset_index(resultDF).iloc[:,1:]
csdDF = pd.DataFrame(csdCol.find({}, {'_id': 0}))
csdDF

popLocDF = popDF[popDF['행정기관'] != '전국']
popLocDF = popLocDF[popDF['구분'] == '총인구수']
csdDF

csdDF.head(20)
# Out:
#      과목    년도  지역     값
# 0    내과  2005  서울  2266
# 1    내과  2005  부산   690
# 2    내과  2005  대구   489
# 3    내과  2005  인천   360
# 4    내과  2005  광주   316
# 5    내과  2005  대전   313
# 6    내과  2005  울산   143
# 7    내과  2005  세종     0
# 8    내과  2005  경기  1473
# 9    내과  2005  강원   220
# 10   내과  2005  충북   193
# 11   내과  2005  충남   242
# 12   내과  2005  전북   315
# 13   내과  2005  전남   280
# 14   내과  2005  경북   316
# 15   내과  2005  경남   428
# 16   내과  2005  제주    80
# 17  신경과  2005  서울   194
# 18  신경과  2005  부산    65
# 19  신경과  2005  대구    58

# %%
resultList = []
for i in range(len(csdDF.index)):
    subj = csdDF.iloc[i,0]
    year = csdDF.iloc[i,1]
    local = csdDF.iloc[i,2]
    value = csdDF.iloc[i,3]
    
    if local == '강원':
        local = '강원도'
    elif local == '경기':
        local = '경기도'
    elif local == '경남':
        local = '경상남도'
    elif local == '경북':
        local = '경상북도'
    elif local == '광주':
        local = '광주광역시'
    elif local == '대구':
        local = '대구광역시'
    elif local == '대전':
        local = '대전광역시'
    elif local == '부산':
        local = '부산광역시'
    elif local == '서울':
        local = '서울특별시'
    elif local == '세종':
        local = '세종특별자치시'
    elif local == '울산':
        local = '울산광역시'
    elif local == '인천':
        local = '인천광역시'
    elif local == '전남':
        local = '전라남도'
    elif local == '전북':
        local = '전라북도'
    elif local == '제주':
        local = '제주특별자치도'
    elif local == '충북':
        local = '충청북도'
    elif local == '충남':
        local = '충청남도'
    
    popDataDF = popLocDF[popLocDF['행정기관']==local]
    popDataDF = popDataDF[popDataDF['년도']==year]
    popDF = popDataDF.iloc[0,2]
    perDoc = value/popDF*1000
    perDoc = perDoc if perDoc==None else 0
    #print('{} - {}, {}, {}, {}, {}, {}'.format(i, subj, year, local, value, popDataDF.iloc[0,2], perDoc))
    resultDict = {'과목':subj,'년도':year,'지역':local,'의사수':value,'인구수':popDF,'값':perDoc}
    resultList.append(resultDict)
    
resultList
# Out:
# [{'과목': '내과', '년도': 2005, '지역': '서울특별시', '의사수': 2266, '인구수': 10167344, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역': '부산광역시', '의사수': 690, '인구수': 3638293, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역': '대구광역시', '의사수': 489, '인구수': 2511306, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역': '인천광역시', '의사수': 360, '인구수': 2600495, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역': '광주광역시', '의사수': 316, '인구수': 1401745, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역': '대전광역시', '의사수': 313, '인구수': 1454638, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역': '울산광역시', '의사수': 143, '인구수': 1087648, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역': '경기도', '의사수': 1473, '인구수': 10697215, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역': '강원도', '의사수': 220, '인구수': 1513110, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역': '충청북도', '의사수': 193, '인구수': 1488803, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역': '충청남도', '의사수': 242, '인구수': 1962646, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역': '전라북도', '의사수': 315, '인구수': 1885335, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역': '전라남도', '의사수': 280, '인구수': 1967205, '값': 0},
#  {'과목': '내과', '년도': 2005, '지역':
값': 0},
#  {'과목': '진단방사선과',
#   '년도': 2005,
#   '지역': '경상남도',
#   '의사수': 101,
#   '인구수': 3160431,
#   '값': 0},
#  {'과목': '진단방사선과',
#   '년도': 2005,
#   '지역': '제주특별자치도',
#   '의사수': 21,
#   '인구수': 557569,
#   '값': 0},
#  {'과목': '방사선종양학과',
#   '년도': 2005,
#   '지역': '서울특별시',
#   '의사수': 54,
#   '인구수': 10167344,
#   '값': 0},
#  {'과목': '방사선종양학과',
#   '년도': 2005,
#   '지역': '부산광역시',
#   '의사수': 14,
#   '인구수': 3638293,
#   '값': 0},
#  {'과목': '방사선종양학과',
#   '년도': 2005,
#   '지역': '대구광역시',
#   '의사수': 10,
#   '인구수': 2511306,
#   '값': 0},
#  {'과목': '방사선종양학과',
#   '년도': 2005,
#   '지역': '인천광역시',
#   '의사수': 7,
#   '인구수': 2600495,
#   '값': 0},
#  {'과목': '방사선종양학과',
#   '년도': 2005,
#   '지역': '광주광역시',
#   '의사수': 3,
#   '인구수': 1401745,
#   '값': 0},
#  {'과목': '방사선종양학과',
#   '년도': 2005,
#   '지역': '대전광역시',
#   '의사수': 5,
#   '인구수': 1454638,
#   '값': 0},
#  {'과목': '방사선종양학과',
#   '년도': 2005,
#   '지역': '울산광역시',
#   '의사수': 3,
#   '인구수': 1087648,
#   '값': 0},
#  {'과목': '방사선종양학과', '년도': 2005, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '방사선종양학과',
#   '년도': 2005,
#   '지역': '경기도',
#   '의사수': 26,
#   '인구수': 10697215,
#   '값': 0},
#  {'과목': '방사선종양학과', '년도': 2005, '지역': '강원도', '의사수': 3, '인구수': 1513110, '값': 0},
#  {'과목': '방사선종양학과', '년도': 2005, '지역': '충청북도', '의사수': 2, '인구수': 1488803, '값': 0},
#  {'과목': '방사선종양학과', '년도': 2005, '지역': '충청남도', '의사수': 4, '인구수': 1962646, '값': 0},
#  {'과목': '방사선종양학과', '년도': 2005, '지역': '전라북도', '의사수': 6, '인구수': 1885335, '값': 0},
#  {'과목': '방사선종양학과', '년도': 2005, '지역': '전라남도', '의사수': 3, '인구수': 1967205, '값': 0},
#  {'과목': '방사선종양학과', '년도': 2005, '지역': '경상북도', '의사수': 1, '인구수': 2688491, '값': 0},
#  {'과목': '방사선종양학과', '년도': 2005, '지역': '경상남도', '의사수': 2, '인구수': 3160431, '값': 0},
#  {'과목': '방사선종양학과',
#   '년도': 2005,
#   '지역': '제주특별자치도',
#   '의사수': 0,
#   '인구수': 557569,
#   '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '서울특별시', '의사수': 200, '인구수': 10167344, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '부산광역시', '의사수': 50, '인구수': 3638293, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '대구광역시', '의사수': 37, '인구수': 2511306, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '인천광역시', '의사수': 15, '인구수': 2600495, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '광주광역시', '의사수': 17, '인구수': 1401745, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '대전광역시', '의사수': 18, '인구수': 1454638, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '울산광역시', '의사수': 7, '인구수': 1087648, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '경기도', '의사수': 72, '인구수': 10697215, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '강원도', '의사수': 13, '인구수': 1513110, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '충청북도', '의사수': 12, '인구수': 1488803, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '충청남도', '의사수': 9, '인구수': 1962646, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '전라북도', '의사수': 13, '인구수': 1885335, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '전라남도', '의사수': 9, '인구수': 1967205, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '경상북도', '의사수': 13, '인구수': 2688491, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '경상남도', '의사수': 22, '인구수': 3160431, '값': 0},
#  {'과목': '병리과', '년도': 2005, '지역': '제주특별자치도', '의사수': 3, '인구수': 557569, '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '서울특별시',
#   '의사수': 192,
#   '인구수': 10167344,
#   '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '부산광역시',
#   '의사수': 42,
#   '인구수': 3638293,
#   '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '대구광역시',
#   '의사수': 34,
#   '인구수': 2511306,
#   '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '인천광역시',
#   '의사수': 23,
#   '인구수': 2600495,
#   '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '광주광역시',
#   '의사수': 25,
#   '인구수': 1401745,
#   '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '대전광역시',
#   '의사수': 15,
#   '인구수': 1454638,
#   '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '울산광역시',
#   '의사수': 4,
#   '인구수': 1087648,
#   '값': 0},
#  {'과목': '진단검사의학과', '년도': 2005, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '경기도',
#   '의사수': 71,
#   '인구수': 10697215,
#   '값': 0},
#  {'과목': '진단검사의학과', '년도': 2005, '지역': '강원도', '의사수': 19, '인구수': 1513110, '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '충청북도',
#   '의사수': 12,
#   '인구수': 1488803,
#   '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '충청남도',
#   '의사수': 13,
#   '인구수': 1962646,
#   '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '전라북도',
#   '의사수': 14,
#   '인구수': 1885335,
#   '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '전라남도',
#   '의사수': 15,
#   '인구수': 1967205,
#   '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '경상북도',
#   '의사수': 22,
#   '인구수': 2688491,
#   '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '경상남도',
#   '의사수': 20,
#   '인구수': 3160431,
#   '값': 0},
#  {'과목': '진단검사의학과',
#   '년도': 2005,
#   '지역': '제주특별자치도',
#   '의사수': 7,
#   '인구수': 557569,
#   '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '서울특별시', '의사수': 28, '인구수': 10167344, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '부산광역시', '의사수': 10, '인구수': 3638293, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '대구광역시', '의사수': 3, '인구수': 2511306, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '인천광역시', '의사수': 2, '인구수': 2600495, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '광주광역시', '의사수': 0, '인구수': 1401745, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '대전광역시', '의사수': 4, '인구수': 1454638, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '울산광역시', '의사수': 3, '인구수': 1087648, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '경기도', '의사수': 17, '인구수': 10697215, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '강원도', '의사수': 2, '인구수': 1513110, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '충청북도', '의사수': 1, '인구수': 1488803, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '충청남도', '의사수': 3, '인구수': 1962646, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '전라북도', '의사수': 3, '인구수': 1885335, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역': '전라남도', '의사수': 1, '인구수': 1967205, '값': 0},
#  {'과목': '결핵과', '년도': 2005, '지역':
'값': 0},
#  {'과목': '응급의학과', '년도': 2005, '지역': '전라남도', '의사수': 13, '인구수': 1967205, '값': 0},
#  {'과목': '응급의학과', '년도': 2005, '지역': '경상북도', '의사수': 19, '인구수': 2688491, '값': 0},
#  {'과목': '응급의학과', '년도': 2005, '지역': '경상남도', '의사수': 11, '인구수': 3160431, '값': 0},
#  {'과목': '응급의학과', '년도': 2005, '지역': '제주특별자치도', '의사수': 4, '인구수': 557569, '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2005,
#   '지역': '서울특별시',
#   '의사수': 24,
#   '인구수': 10167344,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2005,
#   '지역': '부산광역시',
#   '의사수': 14,
#   '인구수': 3638293,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2005,
#   '지역': '대구광역시',
#   '의사수': 10,
#   '인구수': 2511306,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2005,
#   '지역': '인천광역시',
#   '의사수': 10,
#   '인구수': 2600495,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2005,
#   '지역': '광주광역시',
#   '의사수': 4,
#   '인구수': 1401745,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2005,
#   '지역': '대전광역시',
#   '의사수': 7,
#   '인구수': 1454638,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2005,
#   '지역': '울산광역시',
#   '의사수': 11,
#   '인구수': 1087648,
#   '값': 0},
#  {'과목': '직업환경의학과', '년도': 2005, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2005,
#   '지역': '경기도',
#   '의사수': 29,
#   '인구수': 10697215,
#   '값': 0},
#  {'과목': '직업환경의학과', '년도': 2005, '지역': '강원도', '의사수': 4, '인구수': 1513110, '값': 0},
#  {'과목': '직업환경의학과', '년도': 2005, '지역': '충청북도', '의사수': 9, '인구수': 1488803, '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2005,
#   '지역': '충청남도',
#   '의사수': 15,
#   '인구수': 1962646,
#   '값': 0},
#  {'과목': '직업환경의학과', '년도': 2005, '지역': '전라북도', '의사수': 1, '인구수': 1885335, '값': 0},
#  {'과목': '직업환경의학과', '년도': 2005, '지역': '전라남도', '의사수': 6, '인구수': 1967205, '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2005,
#   '지역': '경상북도',
#   '의사수': 17,
#   '인구수': 2688491,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2005,
#   '지역': '경상남도',
#   '의사수': 23,
#   '인구수': 3160431,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2005,
#   '지역': '제주특별자치도',
#   '의사수': 1,
#   '인구수': 557569,
#   '값': 0},
#  {'과목': '예방의학과',
#   '년도': 2005,
#   '지역': '서울특별시',
#   '의사수': 41,
#   '인구수': 10167344,
#   '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '부산광역시', '의사수': 14, '인구수': 3638293, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '대구광역시', '의사수': 9, '인구수': 2511306, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '인천광역시', '의사수': 6, '인구수': 2600495, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '광주광역시', '의사수': 12, '인구수': 1401745, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '대전광역시', '의사수': 5, '인구수': 1454638, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '울산광역시', '의사수': 7, '인구수': 1087648, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '경기도', '의사수': 25, '인구수': 10697215, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '강원도', '의사수': 8, '인구수': 1513110, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '충청북도', '의사수': 3, '인구수': 1488803, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '충청남도', '의사수': 8, '인구수': 1962646, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '전라북도', '의사수': 5, '인구수': 1885335, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '전라남도', '의사수': 6, '인구수': 1967205, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '경상북도', '의사수': 14, '인구수': 2688491, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '경상남도', '의사수': 11, '인구수': 3160431, '값': 0},
#  {'과목': '예방의학과', '년도': 2005, '지역': '제주특별자치도', '의사수': 1, '인구수': 557569, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '서울특별시', '의사수': 2404, '인구수': 10181166, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '부산광역시', '의사수': 737, '인구수': 3611992, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '대구광역시', '의사수': 521, '인구수': 2496115, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '인천광역시', '의사수': 370, '인구수': 2624391, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '광주광역시', '의사수': 330, '인구수': 1407798, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '대전광역시', '의사수': 333, '인구수': 1466158, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '울산광역시', '의사수': 154, '인구수': 1092494, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '경기도', '의사수': 1537, '인구수': 10906033, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '강원도', '의사수': 229, '인구수': 1505420, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '충청북도', '의사수': 201, '인구수': 1494559, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '충청남도', '의사수': 262, '인구수': 1974433, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '전라북도', '의사수': 334, '인구수': 1868365, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '전라남도', '의사수': 284, '인구수': 1942925, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '경상북도', '의사수': 345, '인구수': 2688577, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '경상남도', '의사수': 458, '인구수': 3172857, '값': 0},
#  {'과목': '내과', '년도': 2006, '지역': '제주특별자치도', '의사수': 93, '인구수': 558496, '값': 0},
#  {'과목': '신경과', '년도': 2006, '지역':

#   '값': 0},
#  {'과목': '마취통증의학과',
#   '년도': 2006,
#   '지역': '대구광역시',
#   '의사수': 136,
#   '인구수': 2496115,
#   '값': 0},
#  {'과목': '마취통증의학과',
#   '년도': 2006,
#   '지역': '인천광역시',
#   '의사수': 81,
#   '인구수': 2624391,
#   '값': 0},
#  {'과목': '마취통증의학과',
#   '년도': 2006,
#   '지역': '광주광역시',
#   '의사수': 100,
#   '인구수': 1407798,
#   '값': 0},
#  {'과목': '마취통증의학과',
#   '년도': 2006,
#   '지역': '대전광역시',
#   '의사수': 87,
#   '인구수': 1466158,
#   '값': 0},
#  {'과목': '마취통증의학과',
#   '년도': 2006,
#   '지역': '울산광역시',
#   '의사수': 57,
#   '인구수': 1092494,
#   '값': 0},
#  {'과목': '마취통증의학과', '년도': 2006, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '마취통증의학과',
#   '년도': 2006,
#   '지역': '경기도',
#   '의사수': 422,
#   '인구수': 10906033,
#   '값': 0},
#  {'과목': '마취통증의학과', '년도': 2006, '지역': '강원도', '의사수': 81, '인구수': 1505420, '값': 0},
#  {'과목': '마취통증의학과',
#   '년도': 2006,
#   '지역': '충청북도',
#   '의사수': 72,
#   '인구수': 1494559,
#   '값': 0},
#  {'과목': '마취통증의학과',
#   '년도': 2006,
#   '지역': '충청남도',
#   '의사수': 86,
#   '인구수': 1974433,
#   '값': 0},
#  {'과목': '마취통증의학과',
#   '년도': 2006,
#   '지역': '전라북도',
#   '의사수': 103,
#   '인구수': 1868365,
#   '값': 0},
#  {'과목': '마취통증의학과',
#   '년도': 2006,
#   '지역': '전라남도',
#   '의사수': 104,
#   '인구수': 1942925,
#   '값': 0},
#  {'과목': '마취통증의학과',
#   '년도': 2006,
#   '지역': '경상북도',
#   '의사수': 127,
#   '인구수': 2688577,
#   '값': 0},
#  {'과목': '마취통증의학과',
#   '년도': 2006,
#   '지역': '경상남도',
#   '의사수': 138,
#   '인구수': 3172857,
#   '값': 0},
#  {'과목': '마취통증의학과',
#   '년도': 2006,
#   '지역': '제주특별자치도',
#   '의사수': 26,
#   '인구수': 558496,
#   '값': 0},
#  {'과목': '산부인과',
#   '년도': 2006,
#   '지역': '서울특별시',
#   '의사수': 1217,
#   '인구수': 10181166,
#   '값': 0},
#  {'과목': '산부인과', '년도': 2006, '지역': '부산광역시', '의사수': 389, '인구수': 3611992, '값': 0},
# ...
#  {'과목': '핵의학과', '년도': 2006, '지역': '부산광역시', '의사수': 5, '인구수': 3611992, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '대구광역시', '의사수': 4, '인구수': 2496115, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '인천광역시', '의사수': 5, '인구수': 2624391, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '광주광역시', '의사수': 1, '인구수': 1407798, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '대전광역시', '의사수': 3, '인구수': 1466158, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '울산광역시', '의사수': 1, '인구수': 1092494, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '경기도', '의사수': 13, '인구수': 10906033, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '강원도', '의사수': 1, '인구수': 1505420, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '충청북도', '의사수': 0, '인구수': 1494559, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '충청남도', '의사수': 1, '인구수': 1974433, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '전라북도', '의사수': 4, '인구수': 1868365, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '전라남도', '의사수': 4, '인구수': 1942925, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '경상북도', '의사수': 1, '인구수': 2688577, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '경상남도', '의사수': 1, '인구수': 3172857, '값': 0},
#  {'과목': '핵의학과', '년도': 2006, '지역': '제주특별자치도', '의사수': 1, '인구수': 558496, '값': 0},
#  {'과목': '가정의학과',
#   '년도': 2006,
#   '지역': '서울특별시',
#   '의사수': 891,
#   '인구수': 10181166,
#   '값': 0},
#  {'과목': '가정의학과',
#   '년도': 2006,
#   '지역': '부산광역시',
#   '의사수': 229,
#   '인구수': 3611992,
#   '값': 0},
#  {'과목': '가정의학과',
#   '년도': 2006,
#   '지역': '대구광역시',
#   '의사수': 154,
#   '인구수': 2496115,
#   '값': 0},
#  {'과목': '가정의학과',
#   '년도': 2006,
#   '지역': '인천광역시',
#   '의사수': 175,
#   '인구수': 2624391,
#   '값': 0},
#  {'과목': '가정의학과',
#   '년도': 2006,
#   '지역': '광주광역시',
#   '의사수': 100,
#   '인구수': 1407798,
#   '값': 0},
#  {'과목': '가정의학과',
#   '년도': 2006,
#   '지역': '대전광역시',
#   '의사수': 138,
#   '인구수': 1466158,
#   '값': 0},
#  {'과목': '가정의학과', '년도': 2006, '지역': '울산광역시', '의사수': 48, '인구수': 1092494, '값': 0},
#  {'과목': '가정의학과', '년도': 2006, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '가정의학과', '년도': 2006, '지역': '경기도', '의사수': 688, '인구수': 10906033, '값': 0},
#  {'과목': '가정의학과', '년도': 2006, '지역': '강원도', '의사수': 75, '인구수': 1505420, '값': 0},
#  {'과목': '가정의학과', '년도': 2006, '지역': '충청북도', '의사수': 93, '인구수': 1494559, '값': 0},
#  {'과목': '가정의학과', '년도': 2006, '지역': '충청남도', '의사수': 129, '인구수': 1974433, '값': 0},
#  {'과목': '가정의학과', '년도': 2006, '지역': '전라북도', '의사수': 185, '인구수': 1868365, '값': 0},
#  {'과목': '가정의학과', '년도': 2006, '지역': '전라남도', '의사수': 142, '인구수': 1942925, '값': 0},
#  {'과목': '가정의학과', '년도': 2006, '지역': '경상북도', '의사수': 146, '인구수': 2688577, '값': 0},
#  {'과목': '가정의학과', '년도': 2006, '지역': '경상남도', '의사수': 157, '인구수': 3172857, '값': 0},
#  {'과목': '가정의학과',
#   '년도': 2006,
#   '지역': '제주특별자치도',
#   '의사수': 35,
#   '인구수': 558496,
#   '값': 0},
#  {'과목': '응급의학과',
#   '년도': 2006,
#   '지역': '서울특별시',
#   '의사수': 98,
#   '인구수': 10181166,
#   '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '부산광역시', '의사수': 13, '인구수': 3611992, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '대구광역시', '의사수': 11, '인구수': 2496115, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '인천광역시', '의사수': 19, '인구수': 2624391, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '광주광역시', '의사수': 20, '인구수': 1407798, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '대전광역시', '의사수': 13, '인구수': 1466158, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '울산광역시', '의사수': 7, '인구수': 1092494, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '경기도', '의사수': 65, '인구수': 10906033, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '강원도', '의사수': 18, '인구수': 1505420, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '충청북도', '의사수': 4, '인구수': 1494559, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '충청남도', '의사수': 17, '인구수': 1974433, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '전라북도', '의사수': 15, '인구수': 1868365, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '전라남도', '의사수': 15, '인구수': 1942925, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '경상북도', '의사수': 24, '인구수': 2688577, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '경상남도', '의사수': 13, '인구수': 3172857, '값': 0},
#  {'과목': '응급의학과', '년도': 2006, '지역': '제주특별자치도', '의사수': 6, '인구수': 558496, '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2006,
#   '지역': '서울특별시',
#   '의사수': 27,
#   '인구수': 10181166,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2006,
#   '지역': '부산광역시',
#   '의사수': 13,
#   '인구수': 3611992,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2006,
#   '지역': '대구광역시',
#   '의사수': 13,
#   '인구수': 2496115,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2006,
#   '지역': '인천광역시',
#   '의사수': 10,
#   '인구수': 2624391,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2006,
#   '지역': '광주광역시',
#   '의사수': 4,
#   '인구수': 1407798,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2006,
#   '지역': '대전광역시',
#   '의사수': 8,
#   '인구수': 1466158,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2006,
#   '지역': '울산광역시',
#   '의사수': 12,
#   '인구수': 1092494,
#   '값': 0},
#  {'과목': '직업환경의학과', '년도': 2006, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2006,
#   '지역': '경기도',
#   '의사수': 33,
#   '인구수': 10906033,
#   '값': 0},
#  {'과목': '직업환경의학과', '년도': 2006, '지역': '강원도', '의사수': 3, '인구수': 1505420, '값': 0},
#  {'과목': '직업환경의학과', '년도': 2006, '지역': '충청북도', '의사수': 9, '인구수': 1494559, '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2006,
#   '지역': '충청남도',
#   '의사수': 14,
#   '인구수': 1974433,
#   '값': 0},
#  {'과목': '직업환경의학과', '년도': 2006, '지역': '전라북도', '의사수': 1, '인구수': 1868365, '값': 0},
#  {'과목': '직업환경의학과', '년도': 2006, '지역': '전라남도', '의사수': 5, '인구수': 1942925, '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2006,
#   '지역': '경상북도',
#   '의사수': 16,
#   '인구수': 2688577,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2006,
#   '지역': '경상남도',
#   '의사수': 27,
#   '인구수': 3172857,
#   '값': 0},
#  {'과목': '직업환경의학과',
#   '년도': 2006,
#   '지역': '제주특별자치도',
#   '의사수': 1,
#   '인구수': 558496,
#   '값': 0},
#  {'과목': '예방의학과',
#   '년도': 2006,
#   '지역': '서울특별시',
#   '의사수': 39,
#   '인구수': 10181166,
#   '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '부산광역시', '의사수': 15, '인구수': 3611992, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '대구광역시', '의사수': 9, '인구수': 2496115, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '인천광역시', '의사수': 5, '인구수': 2624391, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '광주광역시', '의사수': 10, '인구수': 1407798, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '대전광역시', '의사수': 4, '인구수': 1466158, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '울산광역시', '의사수': 7, '인구수': 1092494, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '세종특별자치시', '의사수': 0, '인구수': 0, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '경기도', '의사수': 28, '인구수': 10906033, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '강원도', '의사수': 9, '인구수': 1505420, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '충청북도', '의사수': 2, '인구수': 1494559, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '충청남도', '의사수': 8, '인구수': 1974433, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '전라북도', '의사수': 4, '인구수': 1868365, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '전라남도', '의사수': 7, '인구수': 1942925, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '경상북도', '의사수': 15, '인구수': 2688577, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '경상남도', '의사수': 16, '인구수': 3172857, '값': 0},
#  {'과목': '예방의학과', '년도': 2006, '지역': '제주특별자치도', '의사수': 1, '인구수': 558496, '값': 0},
#  {'과목': '내과', '년도': 2007, '지역': '서울특별시', '의사수': 2511, '인구수': 10192710, '값': 0},
#  {'과목': '내과', '년도': 2007, '지역':