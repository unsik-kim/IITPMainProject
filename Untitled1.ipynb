# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
import connectDB
import pandas as pd
import plotly.graph_objects as go

# DB 연결
myclient = connectDB.connectDB()

myDB = myclient['FriDB']
popCol = myDB['Population']
popCol2 = myDB['Population2']
csdCol = myDB['CitySubjectDoc']

popDF = pd.DataFrame(popCol.find({}, {'_id': 0}))
csdDF = pd.DataFrame(csdCol.find({}, {'_id': 0}))

# %%
def makeFigure():
    
    
    fig = px.bar(csdDF,
                 x='값',
                 y='과목',
                 height=1000,
                 range_x=[0, 16000],
                 orientation='h',
                 color='지역',
                 animation_frame='년도'
                 )

    fig.update_layout(
        margin=dict(l=0, r=0, t=100, b=0),
        font=dict(family='Malgun Gothic', size=13, color='rgb(67, 67, 67)'),
        yaxis=dict(categoryorder='total ascending'),
        updatemenus=[{'buttons': [{'args': [None, {'frame': {'duration':
                                                             1000, 'redraw': True}, 'mode':
                                                   'immediate', 'fromcurrent':
                                                   True, 'transition':
                                                   {'duration': 1000, 'easing':
                                                       'quadratic-in-out'}}]}]}]
    )

    return fig

# %%
csdDF
# Out:
#          과목    년도  지역     값
# 0        내과  2005  서울  2266
# 1        내과  2005  부산   690
# 2        내과  2005  대구   489
# 3        내과  2005  인천   360
# 4        내과  2005  광주   316
# ...     ...   ...  ..   ...
# 6183  예방의학과  2018  전북     5
# 6184  예방의학과  2018  전남     7
# 6185  예방의학과  2018  경북    17
# 6186  예방의학과  2018  경남    11
# 6187  예방의학과  2018  제주     2
#
# [6188 rows x 4 columns]

# %%
popDF = popDF[popDF['구분']=='계']
popDF = popDF[popDF['구간']=='총 인구수']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '구간'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-4808afc5af0b> in <module>
#       1 popDF = popDF[popDF['구분']=='계']
# ...

# %%
popDF = pd.DataFrame(popCol.find({}, {'_id': 0}))
popDF.groupby('행정기관').mean()
# Out:
#                  인구수
# 행정기관
# 가평군     38427.047619
# 강남구    370063.619048
# 강동구    320823.952381
# 강릉시    142971.428571
# 강북구    231875.546667
# ...              ...
# 화천군     16817.571429
# 회원구    139640.916667
# 횡성군     30638.261905
# 효자출장소   96516.222222
# 흥덕구    226794.240000
#
# [336 rows x 1 columns]

# %%
popDF = pd.read_excel('data/1992_2019 행정구역 시군구별 성별 인구수.xlsx',thousands = ',')

dataList = []
for i in range(len(popDF.index)):
    for j in range(len(popDF.columns[3:])):
       dataList.append({'행정기관': popDF.iloc[i,0], '구분': popDF.iloc[i,1], '인구수': popDF.iloc[i,j+3], '년도': popDF.columns[j+3]})

# %%
len(dataList)
# Out:
# 30744

# %%
popCol2.insert_many(dataList)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# <ipython-input-4-cf35d8801bf6> in <module>
# ----> 1 popCol2.insert_many(dataList)
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     759         blk = _Bulk(self, ordered, bypass_document_validation)
#     760         blk.ops = [doc for doc in gen()]
# --> 761         blk.execute(write_concern, session=session)
#     762         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     763
#
# ~\anaconda3\lib\site-packages\pymongo\bulk.py in execute(self, write_concern, session)
#     526                 self.execute_no_results(sock_info, generator)
#     527         else:
# --> 528             return self.execute_command(generator, write_concern, session)
#     529
#     530
#
# ...

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
import connectDB
import pandas as pd
import plotly.graph_objects as go

# DB 연결
myclient = connectDB.connectDB()

myDB = myclient['FriDB']
popCol = myDB['Population2']
csdCol = myDB['CitySubjectDoc']

popDF = pd.DataFrame(popCol.find({}, {'_id': 0}))
csdDF = pd.DataFrame(csdCol.find({}, {'_id': 0}))

popAllDF = popDF[popDF['행정기관'] == '전국']
popAllDF = popAllDF[popDF['구분'] == '총인구수']
resultDF = popDF.iloc[13:, 2:4]
pd.DataFrame.reset_index(resultDF).iloc[:,1:]
csdDF = pd.DataFrame(csdCol.find({}, {'_id': 0}))
csdDF

popLocDF = popDF[popDF['행정기관'] != '전국']
popLocDF = popLocDF[popDF['구분'] == '총인구수']
print(popAllDF)
print(popLocDF.iloc[0])
print(popLocDF)
print(csdDF.groupby('지역').max())

popLocDF = popLocDF[popLocDF['행정기관']=='충청남도']
popLocDF = popLocDF[popLocDF['년도']=='2002']
# Out:
#    행정기관    구분         인구수      년도
# 0    전국  총인구수  44503200.0  1992 년
# 1    전국  총인구수  45001113.0  1993 년
# 2    전국  총인구수  45416339.0  1994 년
# 3    전국  총인구수  45858029.0  1995 년
# 4    전국  총인구수  46266256.0  1996 년
# 5    전국  총인구수  46684069.0  1997 년
# 6    전국  총인구수  46991171.0  1998 년
# 7    전국  총인구수  47335678.0  1999 년
# 8    전국  총인구수  47732558.0  2000 년
# 9    전국  총인구수  48021543.0  2001 년
# 10   전국  총인구수  48229948.0  2002 년
# 11   전국  총인구수  48386823.0  2003 년
# 12   전국  총인구수  48583805.0  2004 년
# 13   전국  총인구수  48782274.0  2005 년
# 14   전국  총인구수  48991779.0  2006 년
# 15   전국  총인구수  49268928.0  2007 년
# 16   전국  총인구수  49540367.0  2008 년
# 17   전국  총인구수  49773145.0  2009 년
# 18   전국  총인구수  50515666.0  2010 년
# 19   전국  총인구수  50734284.0  2011 년
# 20   전국  총인구수  50948272.0  2012 년
# 21   전국  총인구수  51141463.0  2013 년
# 22   전국  총인구수  51327916.0  2014 년
# 23   전국  총인구수  51529338.0  2015 년
# 24   전국  총인구수  51696216.0  2016 년
# 25   전국  총인구수  51778544.0  2017 년
# ...

# %%
for i in csdDF.index:
    year = csdDF.iloc[i,1]
    local = csdDF.iloc[i,2]
    value = csdDF.iloc[1,3]
    
    if local ='강원':
        local = '강원도'
    elif local ='경기':
        local = '경기도'
    elif local ='경남':
        local = '경상남도'
    elif local ='경북':
        local = '경상북도'
    elif local ='광주':
        local = '광주광역시'
    elif local ='대구':
        local = '대구광역시'
    elif local ='대전':
        local = '대전광역시'
    elif local ='부산':
        local = '부산광역시'
    elif local ='서울':
        local = '서울특별시'
    elif local ='세종':
        local = '세종특별자치시'
    elif local ='울산':
        local = '울산광역시'
    elif local ='인천':
        local = '인천광역시'
    elif local ='전남':
        local = '전라남도'
    elif local ='전북':
        local = '전라북도'
    elif local ='제주':
        local = '제주특별자치도'
    elif local ='충북':
        local = '충청북도'
    
    popLocDF[popLocDF['행정기관']==local]
# Out:
# 과목      내과
# 년도    2005
# 지역      서울
# 값     2266
# Name: 0, dtype: object
# 과목      내과
# 년도    2005
# 지역      부산
# 값      690
# Name: 1, dtype: object
# 과목      내과
# 년도    2005
# 지역      대구
# 값      489
# Name: 2, dtype: object
# 과목      내과
# 년도    2005
# 지역      인천
# 값      360
# Name: 3, dtype: object
# 과목      내과
# 년도    2005
# 지역      광주
# 값      316
# Name: 4, dtype: object
# 과목      내과
# 년도    2005
# 지역      대전
# 값      313
# Name: 5, dtype: object
# 과목      내과
# 년도    2005
# 지역      울산
# 값      143
# Name: 6, dtype: object
# 과목      내과
# 년도    2005
# 지역      세종
# 값        0
# Name: 7, dtype: object
# 과목      내과
# 년도    2005
# 지역      경기
# 값     1473
# Name: 8, dtype: object
# 과목      내과
# 년도    2005
# 지역      강원
# 값      220
# Name: 9, dtype: object
# 과목      내과
# 년도    2005
# 지역      충북
# 값      193
# Name: 10, dtype: object
# 과목      내과
# 년도    2005
# 지역      충남
# 값      242
# Name: 11, dtype: object
# 과목      내과
# 년도    2005
# 지역      전북
# 값      315
# ...
